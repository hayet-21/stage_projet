# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/part3-icecat/132234_FR.xlsx
# /kaggle/input/katia-data/Data1 (1).csv
# /kaggle/input/part2-icecat/132234_FR.csv
# /kaggle/input/stp-dataset/2DEVEA_pca_cat.csv
# /kaggle/input/stp-dataset/DIFOX-24607888 (1).csv
# /kaggle/input/stp-dataset/cid_export_04072023.csv
# /kaggle/input/stp-dataset/EET_DGF (1).csv
# /kaggle/input/stp-dataset/argor10072024 (1).csv
# /kaggle/input/stp-dataset/Supplies24_30062023.csv
# /kaggle/input/stp-dataset/travion.csv
# /kaggle/input/stp-dataset/Arles (1).csv
# /kaggle/input/stp-dataset/imcopex.csv
# /kaggle/input/stp-dataset/Copaco.csv
# /kaggle/input/stp-dataset/1DGFTECHNOLOGIE_mgf_cat.csv
# /kaggle/input/stp-dataset/TOPUS_STOCKLIST_DGF (2).csv
# /kaggle/input/stp-dataset/eparts.csv
# /kaggle/input/stp-dataset/tarox (1).csv
# /kaggle/input/stp-dataset/dexxon (1).csv
# /kaggle/input/stp-dataset/FlexIT (1).csv
# /kaggle/input/stp-dataset/1346094 (1).csv
# /kaggle/input/stp-dataset/axro.csv
# /kaggle/input/stp-dataset/terra.csv

# %%
import pandas as pd

file_path = r"/kaggle/input/stp-dataset/1DGFTECHNOLOGIE_mgf_cat.csv"

# Liste des encodages à essayer
encodings = ['utf-8', 'ISO-8859-1', 'latin1']

for encoding in encodings:
    try:
        # Tente de lire le fichier CSV avec l'encodage spécifié et un point-virgule comme séparateur
        DGFTECH = pd.read_csv(file_path, encoding=encoding, sep=';', on_bad_lines='skip', engine='python')
        print(f"File successfully loaded with {encoding} encoding.")
        break  # Si le fichier est lu avec succès, sortir de la boucle
    except FileNotFoundError:
        print("Error: File not found at", file_path)
        break  # Si le fichier n'est pas trouvé, sortir de la boucle
    except UnicodeDecodeError as e:
        print(f"Error with {encoding} encoding:", e)
    except Exception as e:
        print("Error:", e)

# Vérifiez si le DataFrame a été créé avec succès
if 'DGFTECH' in locals():
    print(DGFTECH.info())
else:
    print("Failed to load the file with the provided encodings.")
# Out:
# Error with utf-8 encoding: 'utf-8' codec can't decode byte 0xe9 in position 1230: invalid continuation byte
# File successfully loaded with ISO-8859-1 encoding.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10178 entries, 0 to 10177
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   CodeArticleWeb                        10178 non-null  object
#  1   CodeArticle                           10178 non-null  object
#  2   RefFournisseur                        10178 non-null  object
#  3   GenCode                               10131 non-null  object
#  4   Designation_Longue                    10178 non-null  object
#  5   Groupe                                10177 non-null  object
#  6   Marque                                10178 non-null  object
#  7   Stock                                 10178 non-null  int64
#  8   PrixHT_sans_ecop_et_sans_sorecop      10178 non-null  float64
#  9   Ecopart_HT                            10178 non-null  float64
#  10  Sorecop_HT                            10178 non-null  float64
#  11  PrixHT_comprenant_Ecopart_et_Sorecop  10178 non-null  float64
#  12  PrixPublic_HT                         10178 non-null  float64
#  13  Poids                                 10178 non-null  float64
# dtypes: float64(6), int64(1), object(7)
# memory usage: 1.1+ MB
# None

# %%
DGFTECH.head(3)
# Out:
#   CodeArticleWeb  CodeArticle  RefFournisseur        GenCode  \
# 0    0-32LS03CBU  0-32LS03CBU  TQ32LS03CBUXXC  8806094915822
# 1    0-55LST7TCU  0-55LST7TCU  QE55LST7TCUXXC  8806092207356
# 2    0-65LST7TCU  0-65LST7TCU  QE65LST7TCUXXC  8806092213074
#
#                                   Designation_Longue      Groupe   Marque  \
# 0      TV SAMSUNG The Frame 32'' 2023 TQ32LS03CBUXXC  TELEVISION  SAMSUNG
# 1  TV SAMSUNG 55 THE TERRACE QLED 4K SMART TV EXT...  TELEVISION  SAMSUNG
# 2  TV SAMSUNG 65 THE TERRACE QLED 4K SMART TV EXT...  TELEVISION  SAMSUNG
#
#    Stock  PrixHT_sans_ecop_et_sans_sorecop  Ecopart_HT  Sorecop_HT  \
# 0     12                            503.02        3.33         0.0
# 1      2                           3323.00       10.00         0.0
# 2      1                           4154.00       10.00         0.0
#
#    PrixHT_comprenant_Ecopart_et_Sorecop  PrixPublic_HT  Poids
# 0                                506.35            0.0    7.9
# 1                               3333.00            0.0   37.3
# 2                               4164.00            0.0   49.6

# %%
 DGFTECH = DGFTECH[['CodeArticle', 'Groupe', 'Marque', 'Designation_Longue', 
                          'RefFournisseur', 'Stock', 'PrixHT_comprenant_Ecopart_et_Sorecop']]

# %%
columns_rename=['Ref_produit','Categorie','Marque','Description','Ref_fournisseur','Quantite','Prix']

# %%
old_names = ['CodeArticle', 'Groupe', 'Marque', 'Designation_Longue', 
             'RefFournisseur', 'Stock', 'PrixHT_comprenant_Ecopart_et_Sorecop']
# Crée un dictionnaire de renommage
rename_dict = dict(zip(old_names, columns_rename))
DGFTECH  = DGFTECH .rename(columns=rename_dict)

# %%
DGFTECH.head(3)
# Out:
#    Ref_produit   Categorie   Marque  \
# 0  0-32LS03CBU  TELEVISION  SAMSUNG
# 1  0-55LST7TCU  TELEVISION  SAMSUNG
# 2  0-65LST7TCU  TELEVISION  SAMSUNG
#
#                                          Description Ref_fournisseur  \
# 0      TV SAMSUNG The Frame 32'' 2023 TQ32LS03CBUXXC  TQ32LS03CBUXXC
# 1  TV SAMSUNG 55 THE TERRACE QLED 4K SMART TV EXT...  QE55LST7TCUXXC
# 2  TV SAMSUNG 65 THE TERRACE QLED 4K SMART TV EXT...  QE65LST7TCUXXC
#
#    Quantite     Prix
# 0        12   506.35
# 1         2  3333.00
# 2         1  4164.00

# %%
file_path = r"/kaggle/input/stp-dataset/1346094 (1).csv"
# Tente de lire le fichier CSV avec l'encodage spécifié et un point-virgule comme séparateur
df1 = pd.read_csv(file_path)
df1.head(7)
# Out:
#     Part_number            Application        Type         Subtype0  \
# 0       00PA474  Lenovo ThinkPad T460s      Laptop         Keyboard
# 1       00PA556  Lenovo ThinkPad T460s      Laptop         Keyboard
# 2  1200G-2USB-1                         Peripheral  Barcode Scanner
# 3         1K2CF                            Battery           Laptop
# 4    207576-201                         Peripheral       Headphones
# 5    207577-201                         Peripheral       Headphones
# 6    209749-201                         Peripheral       Headphones
#
#           Subtype1                           Description  Stock_level  \
# 0          Unknown         Backlit Keyboard (Portuguese)            1
# 1          Unknown         Backlit Keyboard (Portuguese)            1
# 2              USB         Voyager 1200g Barcode Scanner            1
# 3  Lithium polymer       Main Battery Pack 15.2V 3941mAh            0
# 4          Unknown  Blackwire C5220 Stereo USB-A + 3.5mm            3
# 5          Unknown   Blackwire 5210, Mono, USB-A Headset           10
# 6          Unknown  Blackwire 3220 Stereo, USB-C Headset            0
#
#    Price_EUR  RRP_EUR    Brand Updated    Ean_number Equivalent Part Number
# 0      40.78    97.88  2-Power                   NaN                00PA556
# 1      40.78    97.88  2-Power                   NaN                    NaN
# 2      65.19    89.12  2-Power          5.711045e+12
# 3     151.63   181.95  2-Power          5.704175e+12                  M033W
# 4      57.91    69.50  2-Power          1.722917e+10
# 5      51.70    62.05  2-Power          5.704174e+12
# 6      24.03    33.39  2-Power          1.722917e+10

# %%
df1['Brand'].unique()
# Out:
# array(['2-Power', 'AcBel', 'Acer', 'Asus', 'Brother', 'Canon', 'Chicony',
#        'Compaq', 'Dell', 'Delta', 'Duracell', 'Energizer', 'Fujitsu',
#        'Fujitsu Siemens', 'HP', 'Kyocera', 'Lenovo', 'Lexmark', 'Maxell',
#        'Microsoft', 'Panasonic', 'Poly', 'Saft', 'Samsung', 'Seagate',
#        'Sony', 'Toshiba', 'Varta', 'Xerox', 'Yuasa', 'Zebra'],
#       dtype=object)

# %%
df1 = df1[['Part_number','Type','Brand', 'Description','Stock_level', 'Price_EUR']]

# %%
old_names = ['Part_number','Type' ,'Brand', 'Description','Stock_level', 'Price_EUR']
columns_rename=['Ref_produit','Categorie','Marque','Description','Quantite','Prix']
# Crée un dictionnaire de renommage
rename_dict = dict(zip(old_names, columns_rename))
df1  = df1.rename(columns=rename_dict)
df1.head(3)
# Out:
#     Ref_produit   Categorie   Marque                    Description  Quantite  \
# 0       00PA474      Laptop  2-Power  Backlit Keyboard (Portuguese)         1
# 1       00PA556      Laptop  2-Power  Backlit Keyboard (Portuguese)         1
# 2  1200G-2USB-1  Peripheral  2-Power  Voyager 1200g Barcode Scanner         1
#
#     Prix
# 0  40.78
# 1  40.78
# 2  65.19

# %%
commun_columns=['Ref_produit', 'Marque', 'Description']
df0 = pd.concat([df1[commun_columns], DGFTECH[commun_columns]])

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23134 entries, 0 to 10177
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Ref_produit  23134 non-null  object
#  1   Marque       23134 non-null  object
#  2   Description  23134 non-null  object
# dtypes: object(3)
# memory usage: 722.9+ KB

# %%
file_path =r"/kaggle/input/stp-dataset/2DEVEA_pca_cat.csv"

# Liste des encodages à essayer
encodings = ['utf-8', 'ISO-8859-1', 'latin1']

for encoding in encodings:
    try:
        # Tente de lire le fichier CSV avec l'encodage spécifié et un point-virgule comme séparateur
        df2 = pd.read_csv(file_path, encoding=encoding, sep=';', on_bad_lines='skip', engine='python')
        print(f"File successfully loaded with {encoding} encoding.")
        break  # Si le fichier est lu avec succès, sortir de la boucle
    except FileNotFoundError:
        print("Error: File not found at", file_path)
        break  # Si le fichier n'est pas trouvé, sortir de la boucle
    except UnicodeDecodeError as e:
        print(f"Error with {encoding} encoding:", e)
    except Exception as e:
        print("Error:", e)

# Vérifiez si le DataFrame a été créé avec succès
if 'df2' in locals():
    print(df2.info())
else:
    print("Failed to load the file with the provided encodings.")
# Out:
# Error with utf-8 encoding: 'utf-8' codec can't decode byte 0xe9 in position 1200: invalid continuation byte
# File successfully loaded with ISO-8859-1 encoding.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10033 entries, 0 to 10032
# Data columns (total 13 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   CodeArticleWeb                        10033 non-null  object
#  1   CodeArticle                           10033 non-null  object
#  2   RefFournisseur                        10033 non-null  object
#  3   GenCode                               9988 non-null   object
#  4   Designation_Longue                    10033 non-null  object
#  5   Groupe                                10032 non-null  object
#  6   Marque                                10033 non-null  object
#  7   Stock                                 10033 non-null  int64
#  8   PrixHT_sans_ecop_et_sans_sorecop      10033 non-null  float64
#  9   Ecopart_HT                            10033 non-null  float64
#  10  Sorecop_HT                            10033 non-null  float64
#  11  PrixHT_comprenant_Ecopart_et_Sorecop  10033 non-null  float64
#  12  PrixPublic_HT                         10033 non-null  float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 1019.1+ KB
# None

# %%
df2= df2[['CodeArticle','Groupe','Marque', 'Designation_Longue','RefFournisseur','Stock', 'PrixPublic_HT']]
old_names = ['CodeArticle','Groupe','Marque', 'Designation_Longue','RefFournisseur','Stock', 'PrixPublic_HT ']
columns_rename=['Ref_produit','Categorie','Marque','Description','Ref_fournisseur','Quantite','Prix']
# Crée un dictionnaire de renommage
rename_dict = dict(zip(old_names, columns_rename))
df2  = df2.rename(columns=rename_dict)
df2.head(3)
# Out:
#    Ref_produit   Categorie   Marque  \
# 0  0-32LS03CBU  TELEVISION  SAMSUNG
# 1  0-55LST7TCU  TELEVISION  SAMSUNG
# 2  0-65LST7TCU  TELEVISION  SAMSUNG
#
#                                          Description Ref_fournisseur  \
# 0      TV SAMSUNG The Frame 32'' 2023 TQ32LS03CBUXXC  TQ32LS03CBUXXC
# 1  TV SAMSUNG 55 THE TERRACE QLED 4K SMART TV EXT...  QE55LST7TCUXXC
# 2  TV SAMSUNG 65 THE TERRACE QLED 4K SMART TV EXT...  QE65LST7TCUXXC
#
#    Quantite  PrixPublic_HT
# 0        12            0.0
# 1         2            0.0
# 2         1            0.0

# %%
file_path = r"/kaggle/input/stp-dataset/Arles (1).csv"
# Liste des encodages à essayer
encodings = ['utf-8', 'ISO-8859-1', 'latin1']

for encoding in encodings:
    try:
        # Tente de lire le fichier CSV avec l'encodage spécifié et un point-virgule comme séparateur
        df3 = pd.read_csv(file_path, encoding=encoding, sep=';', on_bad_lines='skip', engine='python')
        print(f"File successfully loaded with {encoding} encoding.")
        break  # Si le fichier est lu avec succès, sortir de la boucle
    except FileNotFoundError:
        print("Error: File not found at", file_path)
        break  # Si le fichier n'est pas trouvé, sortir de la boucle
    except UnicodeDecodeError as e:
        print(f"Error with {encoding} encoding:", e)
    except Exception as e:
        print("Error:", e)

# Vérifiez si le DataFrame a été créé avec succès
if 'df3' in locals():
    print(df3.info())
else:
    print("Failed to load the file with the provided encodings.")
# Out:
# File successfully loaded with utf-8 encoding.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1767 entries, 0 to 1766
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Describtion  1767 non-null   object
#  1   manufactur   1767 non-null   object
#  2   EDP          1767 non-null   object
#  3   QTY          1767 non-null   int64
#  4   Price        1767 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 69.1+ KB
# None

# %%
df3.head(3)
# Out:
#                                      Describtion    manufactur       EDP  QTY  \
# 0           Development Unit Ricoh D8093002 cyan         RICOH  D8093002    2
# 1         Development Unit Ricoh D8093004 yellow         RICOH  D8093004    7
# 2  KYOCERA-MITA Toner (TK580C) (PUx15) (QR code)  KYOCERA MITA   TK-580C   17
#
#    Price
# 0   0.00
# 1   0.00
# 2  64.35

# %%
len(df3['EDP'].unique())
# Out:
# 1766

# %%
df3= df3[['EDP', 'Describtion','manufactur','QTY', 'Price']]
old_names = ['EDP', 'Describtion','manufactur','QTY', 'Price']
columns_rename=['Ref_produit','Description','Ref_fournisseur','Quantite','Prix']
# Crée un dictionnaire de renommage
rename_dict = dict(zip(old_names, columns_rename))
df3  = df3.rename(columns=rename_dict)
df3.head(3)
# Out:
#   Ref_produit                                    Description Ref_fournisseur  \
# 0    D8093002           Development Unit Ricoh D8093002 cyan           RICOH
# 1    D8093004         Development Unit Ricoh D8093004 yellow           RICOH
# 2     TK-580C  KYOCERA-MITA Toner (TK580C) (PUx15) (QR code)    KYOCERA MITA
#
#    Quantite   Prix
# 0         2   0.00
# 1         7   0.00
# 2        17  64.35

# %%
import pandas as pd

file_path =r"/kaggle/input/stp-dataset/Copaco.csv"
df4= pd.read_csv(file_path)
print(df4.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43832 entries, 0 to 43831
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Artikel               43832 non-null  object
#  1   Fabrikantscode        43832 non-null  object
#  2   Merk                  43832 non-null  object
#  3   Omschrijving          43832 non-null  object
#  4   Prijs                 43832 non-null  float64
#  5   Prijs_incl_heffingen  43832 non-null  float64
#  6   Voorraad              43832 non-null  int64
#  7   produktindeling       43832 non-null  object
#  8   UNSPSC_code           43832 non-null  int64
#  9   EAN_code              25259 non-null  object
#  10  status                43832 non-null  int64
#  11  Auvibel               43832 non-null  float64
#  12  Reprobel              43832 non-null  float64
#  13  Recupel               43832 non-null  float64
#  14  Bebat                 43832 non-null  float64
#  15  Datum aanmaken:       0 non-null      float64
#  16  07-17-2024            0 non-null      float64
# dtypes: float64(8), int64(3), object(6)
# memory usage: 5.7+ MB
# None

# %%
df4.head(3)
# Out:
#             Artikel Fabrikantscode  Merk  \
# 0  ACR-DP.PR2EE.X67   DP.PR2EE.X67  Acer
# 1  ACR-DP.PR2EE.X71   DP.PR2EE.X71  Acer
# 2  ACR-DP.Z35WW.P01   DP.Z35WW.P01  Acer
#
#                                         Omschrijving   Prijs  \
# 0             Acer USB Keyboard - BE. Azerty - Black   20.65
# 1   Keyboard Pro2 USB Black QWERTY  US International   13.37
# 2  Predator BiFrost Intel ARC A750 OC - APBF-IA75...  245.00
#
#    Prijs_incl_heffingen  Voorraad produktindeling  UNSPSC_code       EAN_code  \
# 0                 20.77         0    ACRNOT---ASP     43211503  4712842943662
# 1                 13.49       100    ACRP-C---ASP     43000000  4712842943648
# 2                245.00         5    ACRNOT---ASP     43211503  4711121619083
#
#    status  Auvibel  Reprobel  Recupel  Bebat  Datum aanmaken:   07-17-2024
# 0       0      0.0       0.0     0.12    0.0               NaN         NaN
# 1       2      0.0       0.0     0.12    0.0               NaN         NaN
# 2       0      0.0       0.0     0.00    0.0               NaN         NaN

# %%
df4= df4[['Artikel','produktindeling','Merk','Omschrijving','Fabrikantscode','Voorraad', 'Prijs']]
old_names = ['Artikel','produktindeling','Merk','Omschrijving','Fabrikantscode','Voorraad', 'Prijs']
columns_rename=['Ref_produit','Categorie','Marque','Description','Ref_fournisseur','Quantite','Prix']
# Crée un dictionnaire de renommage
rename_dict = dict(zip(old_names, columns_rename))
df4  = df4.rename(columns=rename_dict)
df4.head(3)
# Out:
#         Ref_produit     Categorie Marque  \
# 0  ACR-DP.PR2EE.X67  ACRNOT---ASP   Acer
# 1  ACR-DP.PR2EE.X71  ACRP-C---ASP   Acer
# 2  ACR-DP.Z35WW.P01  ACRNOT---ASP   Acer
#
#                                          Description Ref_fournisseur  \
# 0             Acer USB Keyboard - BE. Azerty - Black    DP.PR2EE.X67
# 1   Keyboard Pro2 USB Black QWERTY  US International    DP.PR2EE.X71
# 2  Predator BiFrost Intel ARC A750 OC - APBF-IA75...    DP.Z35WW.P01
#
#    Quantite    Prix
# 0         0   20.65
# 1       100   13.37
# 2         5  245.00

# %%
file_path = r"/kaggle/input/stp-dataset/DIFOX-24607888 (1).csv"
# Liste des encodages à essayer
encodings = ['utf-8', 'ISO-8859-1', 'latin1']

for encoding in encodings:
    try:
        # Tente de lire le fichier CSV avec l'encodage spécifié et un point-virgule comme séparateur
        df5 = pd.read_csv(file_path, encoding=encoding, sep=';', on_bad_lines='skip', engine='python')
        print(f"File successfully loaded with {encoding} encoding.")
        break  # Si le fichier est lu avec succès, sortir de la boucle
    except FileNotFoundError:
        print("Error: File not found at", file_path)
        break  # Si le fichier n'est pas trouvé, sortir de la boucle
    except UnicodeDecodeError as e:
        print(f"Error with {encoding} encoding:", e)
    except Exception as e:
        print("Error:", e)

# Vérifiez si le DataFrame a été créé avec succès
if 'df5' in locals():
    print(df5.info())
else:
    print("Failed to load the file with the provided encodings.")
# Out:
# File successfully loaded with utf-8 encoding.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36833 entries, 0 to 36832
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Catégorie                 36833 non-null  object
#  1   Désignation catégorie     36833 non-null  object
#  2   N° d'article              36833 non-null  int64
#  3   Désignation de l'article  36833 non-null  object
#  4   Nom du fournisseur        36833 non-null  object
#  5   N° d'art. du fournisseur  36520 non-null  object
#  6   Code barre 1              36267 non-null  float64
#  7   Code barre 2              1172 non-null   float64
#  8   Code barre 3              100 non-null    float64
#  9   Code barre 4              26 non-null     float64
#  10  Code barre 5              13 non-null     float64
#  11  Code barre 6              9 non-null      float64
#  12  Prix de vente             36833 non-null  float64
#  13  Disponibilité (step)      36767 non-null  object
#  14  Nouveautés                19 non-null     float64
#  15  Changements de prix       336 non-null    object
#  16  Fins de référencement     66 non-null     float64
#  17  Sonderversandkosten       36833 non-null  int64
#  18  Gurtmass                  36833 non-null  int64
# dtypes: float64(9), int64(3), object(7)
# memory usage: 5.3+ MB
# None

# %%
df5['Nom du fournisseur'].unique()
# Out:
# array(['keine Marke', 'Fujifilm', 'Kidywolf', 'AgfaPhoto', 'Ilford',
#        'Harman', 'Easypix', 'Kodak', 'Pentax', 'Sony', 'VTech', 'Rollei',
#        'Ricoh', 'Canon', 'Denver', 'Sealife', 'Panasonic', 'Olympus',
#        'Minox', 'Braun Phototechnik', 'Bushnell', 'Enlaps', 'Samyang',
#        'OM System', 'Sekonic', 'Gossen', 'Novoflex', 'Kaiser Fototechnik',
#        'Godox', 'walimex', 'Nikon', 'Blackmagic Design', 'Reflecta',
#        'Hama', 'Walther', 'Deknudt', 'Nielsen Design', 'ZEP', 'Goldbuch',
#        'Zilverstad', 'Daiber', 'Durable', 'Mitsubishi Electric', 'DNP',
#        'Epson', 'Umax-HiTi', 'OEM für Citizen', 'Insta360', 'Kandao',
#        'Transcend', 'Garmin', 'Chasing Innovation', 'Logitech', 'RGBLink',
#        'IPEVO', 'LG', 'Samsung', 'Hisense', 'Sharp', 'Grundig', 'Lenco',
#        'BENQ', 'InFocus', 'Acer', 'Xgimi', 'Philips', 'Hewlett Packard',
#        'Screenplay', 'Kindle', 'Google', 'Apple', 'Strong', 'Imperial',
#        'Sangean', 'TechniSat', 'Kenwood', 'Albrecht', 'Pure', 'Telestar',
#        'Teac', 'Denon', 'Pioneer', 'Audio Technica', 'JVC', 'Marshall',
#        'Bose', 'Klipsch', 'Rode', 'Deity', 'Joby', 'OWL Labs',
#        'König & Meyer', 'In - Akustik', 'OneforAll', 'Sennheiser',
#        'Marmitek', 'Turtle Beach', 'Koss', 'UGREEN', 'TomTom', 'Midland',
#        'Fantec', 'Belkin', 'OneOdio', 'Boompods', 'Jabra', 'Beats',
#        'DIGITUS', 'ednet', 'Plantronics', 'Razer', 'Lenovo',
#        'CONCEPTRONIC', 'Roccat', 'Rapoo', 'AOC', 'Asus', 'MadCatz',
#        'HyperX', 'Xiaomi', 'Suunto', 'JLab', 'Magnat', 'Ultimate Ears',
#        'Dockin', 'Native Union', 'Microsoft', 'Amazon Echo', 'Omnitronic',
#        'ECS IPC', 'Nintendo', 'Millennium 2000', 'Arcade', 'ready2gaming',
#        'PDP', 'Thrustmaster', 'Thermaltake', 'be quiet!', 'LC Power',
#        'PocketBook', 'Tolino', 'Xoro', 'Nokia', 'Vogels', 'Fellowes',
#        'Xlayer', '3M', 'PanzerGlass', 'Wacom', 'Lamy', 'Dell',
#        'BlueWalker', 'Cyberpower', 'APC by Schneider Electric', 'Iiyama',
#        'Fujitsu', 'MSI', 'Verbatim', 'Plustek', 'Microtek', 'Avision',
#        'Kyocera', 'Brother', 'Dymo', 'Clean Office', 'KeySonic',
#        'Evoluent', 'Cherry', 'Corsair', 'Toucan', 'Electronic Arts',
#        'Elinchrom', 'RaidSonic', 'SanDisk', 'Wise', 'AMD', 'Intel',
#        'Rivacase', 'Brennenstuhl', 'Crucial', 'DATACOLOR', 'Level One',
#        'TP-Link', 'Zyxel', 'Netgear', 'D-Link', 'Ubiquiti', 'AVM',
#        'Starlink', 'Freecom', 'Timekettle', 'Casio', 'Gigaset', 'Doro',
#        'Grandstream', 'KMP', 'Motorola', 'OLYMPIA', 'Emporia', 'Beafon',
#        'AGM MOBILE', 'Nothing Phone', 'ZTE', 'realme', 'CAT', 'Fairphone',
#        'Crosscall', 'Nomad', 'Woodcessories', 'Decoded', 'GIGA Fixxoo',
#        'iFixit', 'Medisana', 'Polar', 'Amazfit', 'HUAWEI',
#        'One Button Phone', 'Pitaka', 'DeLonghi', 'Unold', 'Graef',
#        'Cloer', 'Russell Hobbs', 'Braun', 'Bosch', 'ProfiCook', 'Sage',
#        'Steba', 'Bomann', 'Moulinex', 'Ariete', 'Severin', 'Caso',
#        'Stelton', 'Makita', 'Gastroback', 'Clatronic', 'KitchenAid',
#        'Ninja', 'Solis', 'Zwilling', 'WMF', 'Ritter', 'Berkel',
#        'Zassenhaus', 'Beurer', 'Soehnle', 'Joseph Joseph', 'Ooni',
#        'TFA-Dostmann', 'nutribullet', 'Dualit', 'Rommelsbacher', 'Krups',
#        'Melitta', 'Rowenta', 'Gaggia', 'Rocket Espresso Milano',
#        'Siemens', 'Acopino', 'Alessi', 'Leopold Vienna', 'EUREKA',
#        'Didiesse', 'Grimac', 'Bialetti', 'Joerges',
#        'Torrefazione Caffè Pabios di Petralli', 'Tefal', 'Gorenje',
#        'G3Ferrari', 'Weber', 'Campingaz', 'Ankarsrum', 'Gefu', 'Weck',
#        'Princess', 'Levenhuk', 'OTOTO', 'Oral-B', 'Remington', 'SANITAS',
#        'Revlon', 'ProfiCare', 'Dyson', 'Shark', 'Dreame', 'Technoline',
#        'Bresser', 'Mebus', 'Brita', 'BWT', 'Aarke', 'SodaStream', 'Aqvia',
#        'Govee', 'Mobicool', 'EcoFlow', 'Coleman', 'Singer', 'Gritzner',
#        'Kärcher', 'Nilfisk', 'AEG', 'Tineco', 'Trifo', 'ECOVACS',
#        'Black & Decker', 'Leifheit', 'Stadler Form', 'Bauknecht',
#        'Papirho', 'Zipper', 'SpeedComfort', 'Haier', 'BEKO', 'Saeco',
#        'Swirl', 'Menalux', 'Metabo', 'Brabantia', 'Krinner', 'Ansmann',
#        'Varta', 'GP Batteries', 'Energizer', 'Duracell', 'Eneloop',
#        'Anker', 'Hedbox', 'REV', 'Intenso', 'Century', 'Ember', 'Atomos',
#        'Ryobi', 'DeWalt', 'Milwaukee', 'Einhell', 'Gardena', 'Fein',
#        'EasyCover', 'Cullmann', 'Wenger', 'Dicota', 'B&W International',
#        'Lowepro', 'Vanguard', 'mantona', 'Pacsafe', 'B+W', 'Shape',
#        'OP Tech', 'Fidlock', 'STMNT', 'Speck', 'Spigen', 'Dörr', 'KNIPEX',
#        'Fiskars', 'Stanley Black&Decker', 'Wera', 'Wiha', 'SoFlow',
#        'Herma', 'Holzmann', 'Raynox', 'Tether Tools', 'Falcon', 'PGYTECH',
#        'PocketWizard', 'Stealth Gear', 'Buteo Photo Gear', 'POLARPRO',
#        'Visible Dust', 'Green Clean', 'Camgloss', 'Kinetronics',
#        'Carson Optical', 'Zhiyun', 'Discovery', 'Kipon', 'Slik', 'Velbon',
#        'Sachtler', 'Aputure', 'Nanlite', 'Amaran', 'Osram',
#        'Orangemonkie', 'Elmo', 'equip', 'August', 'Ikan', 'Desview',
#        'Portkeys', 'Texas Instruments', 'Parker', 'Sharpie', 'Rotring',
#        'Paper Mate', 'Tesa', 'Inapa', 'Hahnemühle', 'tecno',
#        'Mondi Color Copy', 'Silverlab', 'Polaroid', 'Lexmark', 'DJI',
#        'Scosche', 'Walkstool', 'Original Wolfen', 'Western Digital',
#        'LaCie', 'Seagate', 'Toshiba', 'ADATA', 'Kioxia', 'Kingston',
#        'Goodram', 'Angelbird', 'Micron', 'MyMedia', 'Univers', 'Carrera',
#        'Dickie', 'LEGO', 'Schleich', 'ELMER´S', 'Ravensburger', 'Revell',
#        'Jada', 'Xplora', 'Trousselier', 'Amewi', 'Game Factory',
#        'Ambassador', 'Creagami', 'Theo Klein', 'Smoby', 'BIG', 'Steinel',
#        'WORX', 'Vileda', 'Xavax', 'Felco', 'Opinel', 'Gerber',
#        'Alpen Swiss Tools', 'Silky', 'LotusGrill', 'Alfa Forni', 'ZiiPa',
#        'Looft', 'Laguiole', 'Leica', 'Ermenrich', 'BMI', 'KS Tools',
#        'Gedore', 'Brilliant Tools', 'NWS', 'BESSEY', 'NOVUS',
#        'Brockhaus Heuer', 'Picard', 'Halder', 'Kirschen', 'Leatherman',
#        'Uvex', 'Aerotec', 'Odys', 'Perfectpro', 'Pica-Marker',
#        'Alpen-Maykestag', 'Fischer', 'Klingspor', 'DieMaus', 'NewGarden',
#        '8seasons', 'Wofi Leuchten', 'ab+', 'Piffany Copenhagen',
#        'Broggi Design', 'Sompex', 'XCell', 'Fenix', 'Ledlenser', 'HyCell',
#        'Maglite', 'LinkDesk', 'Switchbot', 'Ring', 'Meross',
#        'Lite Bulb Moments', 'Bold', 'Masterlock', 'Abus',
#        'Ei Electronics', 'Wallbox', 'NRGkick', 'Webasto', 'Easee',
#        'Jackery', 'Hyrican', 'Bluetti', 'Technaxx', 'Grohe', 'Hansgrohe',
#        'Ninebot', 'Victorinox', 'Morakniv', 'Katadyn', 'Tacx', 'Sevylor',
#        'Danubia', 'National Geographic', 'Noblex', 'Staub', 'Le Creuset',
#        'De Buyer', 'Lagostina', 'Fissler', 'Stanley', 'Ballarini', 'Güde',
#        'KAI', 'Miyabi', 'Yaxell', 'Global', 'Dick', 'Grattoni', 'Marcato',
#        'Imperia', 'Emsa', 'KAISER', 'Rösle', 'Bredemeijer', 'Sambonet',
#        'L oca nera', 'Coravin', 'Peugeot', 'Mepal', 'Sigg', 'Chillys',
#        'Asobu', 'Bodum', 'Wesco', 'Secolan', 'Ibena', 'Bugatti',
#        'Rig-Tig', 'PETKIT', 'TensCare', 'heat it'], dtype=object)

# %%
df5= df5[["N° d'art. du fournisseur","Désignation catégorie","Désignation de l'article","Nom du fournisseur","Disponibilité (step)","Prix de vente"]]
old_names = ["N° d'art. du fournisseur","Désignation catégorie","Désignation de l'article","Nom du fournisseur","Disponibilité (step)","Prix de vente"]
columns_rename=['Ref_produit','Categorie','Description','Marque','Quantite','Prix']
# Crée un dictionnaire de renommage
rename_dict = dict(zip(old_names, columns_rename))
df5  = df5.rename(columns=rename_dict)
df5.head(3)
# Out:
#   Ref_produit          Categorie  \
# 0   FPP36SUBW  Travaux photo N&B
# 1     FPP36SW  Travaux photo N&B
# 2       FPPSB  Travaux photo N&B
#
#                                          Description       Marque Quantite  \
# 0   Développement complet SUC N&B app. photo jetable  keine Marke     > 20
# 1   Développement complet film petit format 35mm N&B  keine Marke     > 10
# 2  Développement film + Scan N&B Film pet. format...  keine Marke        5
#
#     Prix
# 0  17.96
# 1  17.96
# 2  11.45

# %%
file_path =r"/kaggle/input/stp-dataset/EET_DGF (1).csv"
# Liste des encodages à essayer
encodings = ['utf-8', 'ISO-8859-1', 'latin1']

for encoding in encodings:
    try:
        # Tente de lire le fichier CSV avec l'encodage spécifié et un point-virgule comme séparateur
        df6 = pd.read_csv(file_path, encoding=encoding, sep='\t', on_bad_lines='skip', engine='python')
        print(f"File successfully loaded with {encoding} encoding.")
        break  # Si le fichier est lu avec succès, sortir de la boucle
    except FileNotFoundError:
        print("Error: File not found at", file_path)
        break  # Si le fichier n'est pas trouvé, sortir de la boucle
    except UnicodeDecodeError as e:
        print(f"Error with {encoding} encoding:", e)
    except Exception as e:
        print("Error:", e)

# Vérifiez si le DataFrame a été créé avec succès
if 'df6' in locals():
    print(df6.info())
else:
    print("Failed to load the file with the provided encodings.")
# Out:
# Error with utf-8 encoding: 'utf-8' codec can't decode byte 0xe2 in position 246: invalid continuation byte
# File successfully loaded with ISO-8859-1 encoding.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1183781 entries, 0 to 1183780
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   Brand Name               1183781 non-null  object
#  1   Item No.                 1183781 non-null  object
#  2   Manufacturer Part No     1183781 non-null  object
#  3   OEM Part Number          252032 non-null   object
#  4   Description              1183731 non-null  object
#  5   Description 2            538098 non-null   object
#  6   Home stock               1183781 non-null  object
#  7   Customers Price          1183778 non-null  object
#  8   EAN/UPC                  351340 non-null   object
#  9   Web Category Name        1183658 non-null  object
#  10  Web Category Tree        1183658 non-null  object
#  11  Item Product Link (Web)  1183778 non-null  object
# dtypes: object(12)
# memory usage: 108.4+ MB
# None

# %%
df6.head()
# Out:
#   Brand Name     Item No. Manufacturer Part No OEM Part Number  \
# 0     Lenovo      00HV340              00HV340             NaN
# 1       Dell        00HV6                00HV6             NaN
# 2     Lenovo      00HV799              00HV799             NaN
# 3     Lenovo  00HW000-RFB          00HW000-RFB             NaN
# 4     Lenovo  00HW001-RFB          00HW001-RFB             NaN
#
#                       Description    Description 2 Home stock Customers Price  \
# 0    RDN PDB to HDD BP power cabl              NaN       0,00           27,00
# 1           Dvd Super-Multi Drive              NaN       0,00           79,20
# 2  PDB to MB for CPU ODD Power ca              NaN       0,00           30,90
# 3                      BATTERY 4C  **Refurbished**       0,00          164,70
# 4       BATTERY 4C YOGA 14 LI-ION  **Refurbished**       0,00          112,80
#
#          EAN/UPC                        Web Category Name  \
# 0            NaN                              Câbles SATA
# 1  5704174278887  Autres pièces de rechange pour notebook
# 2            NaN                                    Autre
# 3            NaN                                    Autre
# 4  5711783852506                                Batteries
#
#                                    Web Category Tree  \
# 0  Pièces pour serveur, notebook & imprimante>Câb...
# 1  Pièces pour serveur, notebook & imprimante>Not...
# 2  Pièces pour serveur, notebook & imprimante>Autre>
# 3  Pièces pour serveur, notebook & imprimante>Autre>
# 4  Pièces pour serveur, notebook & imprimante>Not...
#
#                              Item Product Link (Web)
# 0  https://www.eetgroup.com/fr-fr/itemId?itemid=0...
# 1  https://www.eetgroup.com/fr-fr/itemId?itemid=0...
# 2  https://www.eetgroup.com/fr-fr/itemId?itemid=0...
# 3  https://www.eetgroup.com/fr-fr/itemId?itemid=0...
# 4  https://www.eetgroup.com/fr-fr/itemId?itemid=0...

# %%
df6= df6[["Item No.","Web Category Tree",'Brand Name',"Description",'Home stock', 'Customers Price']]
old_names = ["Item No.","Web Category Tree",'Brand Name',"Description",'Home stock', 'Customers Price']
columns_rename=['Ref_produit','Categorie','Marque','Description','Quantite','Prix']
# Crée un dictionnaire de renommage
rename_dict = dict(zip(old_names, columns_rename))
df6  = df6.rename(columns=rename_dict)
df6.head(3)
# Out:
#   Ref_produit                                          Categorie  Marque  \
# 0     00HV340  Pièces pour serveur, notebook & imprimante>Câb...  Lenovo
# 1       00HV6  Pièces pour serveur, notebook & imprimante>Not...    Dell
# 2     00HV799  Pièces pour serveur, notebook & imprimante>Autre>  Lenovo
#
#                       Description Quantite   Prix
# 0    RDN PDB to HDD BP power cabl     0,00  27,00
# 1           Dvd Super-Multi Drive     0,00  79,20
# 2  PDB to MB for CPU ODD Power ca     0,00  30,90

# %%
df6.describe()
# Out:
#        Ref_produit                                          Categorie  \
# count      1183781                                            1183658
# unique     1183781                                                627
# top        00HV340  Pièces pour serveur, notebook & imprimante>Autre>
# freq             1                                             706189
#
#          Marque Description Quantite     Prix
# count   1183781     1183731  1183781  1183778
# unique      431      711836      932    46922
# top      Lenovo   BDPLANAR      0,00    11,10
# freq     212823        3748  1153411    12881

# %%
file_path=r"/kaggle/input/stp-dataset/FlexIT (1).csv"
# Liste des encodages à essayer
encodings = ['utf-8', 'ISO-8859-1', 'latin1']

for encoding in encodings:
    try:
        # Tente de lire le fichier CSV avec l'encodage spécifié et un point-virgule comme séparateur
        df7= pd.read_csv(file_path, encoding=encoding, sep=';', on_bad_lines='skip', engine='python')
        print(f"File successfully loaded with {encoding} encoding.")
        break  # Si le fichier est lu avec succès, sortir de la boucle
    except FileNotFoundError:
        print("Error: File not found at", file_path)
        break  # Si le fichier n'est pas trouvé, sortir de la boucle
    except UnicodeDecodeError as e:
        print(f"Error with {encoding} encoding:", e)
    except Exception as e:
        print("Error:", e)

# Vérifiez si le DataFrame a été créé avec succès
if 'df7' in locals():
    print(df7.info())
else:
    print("Failed to load the file with the provided encodings.")
# Out:
# File successfully loaded with utf-8 encoding.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 799 entries, 0 to 798
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              797 non-null    object
#  1   Manufacturer Part Number  799 non-null    object
#  2   Flex IT Part Number       799 non-null    object
#  3   Description               799 non-null    object
#  4   Stock Quantity            799 non-null    int64
#  5   Sales Price               799 non-null    float64
#  6   SRP                       799 non-null    float64
#  7   Status                    799 non-null    object
#  8   Alias                     799 non-null    object
#  9   Incoming Quantity         799 non-null    int64
#  10  Incoming Date             4 non-null      object
#  11  Status Description        799 non-null    object
#  12  Category                  799 non-null    object
#  13  Product Group             799 non-null    object
#  14  IceCat ID                 4 non-null      float64
#  15  Length                    750 non-null    float64
#  16  Width                     750 non-null    float64
#  17  Height                    748 non-null    float64
#  18  Cubage                    748 non-null    float64
#  19  Weight                    794 non-null    float64
#  20  EAN                       52 non-null     float64
#  21  Item number no status     799 non-null    int64
# dtypes: float64(9), int64(3), object(10)
# memory usage: 137.5+ KB
# None

# %%
df7= df7[["Manufacturer Part Number","Category",'Manufacturer',"Description",'Stock Quantity', 'SRP']]
old_names = ["Manufacturer Part Number","Category",'Manufacturer',"Description","Fournisseur",'Stock Quantity', 'SRP']
columns_rename=['Ref_produit','Categorie','Marque','Description','Fournisseur','Quantite','Prix']
# Crée un dictionnaire de renommage
rename_dict = dict(zip(old_names, columns_rename))
df7 = df7.rename(columns=rename_dict)
df7['Fournisseur'] = 'Flex IT'
df7.head(3)
# Out:
#    Ref_produit                Categorie Marque  \
# 0  409H3B/A-AS  Mobile Phones/Handhelds  APPLE
# 1  4G2D3B/A-AS  Mobile Phones/Handhelds  APPLE
# 2  4G2E3B/A-AS  Mobile Phones/Handhelds  APPLE
#
#                                          Description  Quantite   Prix  \
# 0  Apple Watch Series 6 44mm LTE Graphite SS Stai...       212  219.0
# 1  Apple Watch Series 6 44mm LTE Gold ALU Aluminu...        34  189.0
# 2  Apple Watch Series 6 44mm LTE Space Gray ALU A...         1  189.0
#
#   Fournisseur
# 0     Flex IT
# 1     Flex IT
# 2     Flex IT

# %%
file_path=r"/kaggle/input/stp-dataset/Supplies24_30062023.csv"
# Liste des encodages à essayer
encodings = ['utf-8', 'ISO-8859-1', 'latin1']

for encoding in encodings:
    try:
        # Tente de lire le fichier CSV avec l'encodage spécifié et un point-virgule comme séparateur
        df8= pd.read_csv(file_path, encoding=encoding, sep=';', on_bad_lines='skip', engine='python')
        print(f"File successfully loaded with {encoding} encoding.")
        break  # Si le fichier est lu avec succès, sortir de la boucle
    except FileNotFoundError:
        print("Error: File not found at", file_path)
        break  # Si le fichier n'est pas trouvé, sortir de la boucle
    except UnicodeDecodeError as e:
        print(f"Error with {encoding} encoding:", e)
    except Exception as e:
        print("Error:", e)

# Vérifiez si le DataFrame a été créé avec succès
if 'df8' in locals():
    print(df8.info())
else:
    print("Failed to load the file with the provided encodings.")
# Out:
# Error with utf-8 encoding: 'utf-8' codec can't decode byte 0x82 in position 1: invalid start byte
# File successfully loaded with ISO-8859-1 encoding.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8235 entries, 0 to 8234
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Rfrence             8235 non-null   object
#  1   Prix                  8235 non-null   object
#  2   Qty                   8235 non-null   int64
#  3   Artikel Beschreibung  8235 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 257.5+ KB
# None

# %%
def clean_price(price):
    if isinstance(price, str):
        # Remplacer les virgules par des points et enlever les ?
        price = price.replace(',', '.').replace('?', '')
    try:
        return float(price)
    except ValueError:
        return None

# Appliquer la fonction à la colonne 'Prix'
df8['Prix'] = df8['Prix'].apply(clean_price)

# %%
df8= df8[["Rfrence","Artikel Beschreibung",'Qty', 'Prix']]
old_names = ["Rfrence","Artikel Beschreibung",'Qty', 'Prix']
columns_rename=['Ref_produit','Description','Quantite','Prix']
# Crée un dictionnaire de renommage
rename_dict = dict(zip(old_names, columns_rename))
df8 = df8.rename(columns=rename_dict)
df8.head(3)
# Out:
#    Ref_produit                                        Description  Quantite  \
# 0    AP18020A6  ORIGINAL Agfa Photo Papier Blanc AP18020A6 Le ...         1
# 1  APB1000SETD  ORIGINAL Agfa Photo Multipack Noir(e) / Cyan /...         1
# 2    APB1100BD  ORIGINAL Agfa Photo Cartouche d'encre Noir(e) ...         0
#
#    Prix
# 0  0.53
# 1  6.86
# 2  2.66

# %%
# Extraction du premier mot de la description pour la colonne "Marque"
df8['Marque'] = df8['Description'].apply(lambda x: x.split()[1] if pd.notna(x) else 'Inconnu')
df8
# Out:
#            Ref_produit                                        Description  \
# 0            AP18020A6  ORIGINAL Agfa Photo Papier Blanc AP18020A6 Le ...
# 1          APB1000SETD  ORIGINAL Agfa Photo Multipack Noir(e) / Cyan /...
# 2            APB1100BD  ORIGINAL Agfa Photo Cartouche d'encre Noir(e) ...
# 3          APB1100SETD  ORIGINAL Agfa Photo Multipack Noir(e) / Cyan /...
# 4             APB123BD  ORIGINAL Agfa Photo Cartouche d'encre Noir(e) ...
# ...                ...                                                ...
# 8230  800263-205 12PCK  ORIGINAL Zebra Etiquettes 800263-205 12PCK Z-S...
# 8231        800284-605     ORIGINAL Zebra Etiquettes 800284-605 Z-Perform
# 8232             87000  ORIGINAL Zebra Etiquettes 87000 Z-Select Pack ...
# 8233   GK42-202220-000   ORIGINAL Zebra Imprimante GK42-202220-000 GK420d
# 8234   GK42-202520-000   ORIGINAL Zebra Imprimante GK42-202520-000 GK420d
#
#       Quantite    Prix Marque
# 0            1    0.53   Agfa
# 1            1    6.86   Agfa
# 2            0    2.66   Agfa
# 3            0    7.49   Agfa
# 4            1    3.67   Agfa
# ...        ...     ...    ...
# 8230         1  149.19  Zebra
# 8231         1  160.36  Zebra
# 8232         1   66.25  Zebra
# 8233         1  348.37  Zebra
# 8234         1  248.84  Zebra
#
# [8235 rows x 5 columns]

# %%
df8['Marque'].unique()
# Out:
# array(['Agfa', 'AVERY', 'Brother', 'Canon', 'Colop', 'Dell', 'Develop',
#        'Diverse', 'DYMO', 'Epson', 'Fujitsu', 'Honeywell', 'HP', 'Jabra',
#        'Konica', 'Kyocera', 'Lenovo', 'Lexmark', 'Logitech', 'Mita',
#        'Mitsubishi', 'MyClean', 'Nashuatec', 'NewStar', 'NRG', 'OKI',
#        'Olivetti', 'Panasonic', 'Peach', 'Plustek', 'Prindo', 'Quantum',
#        'Ricoh', 'Riso', 'Samsung', 'Seiko', 'Sharp', 'Sony', 'Summer',
#        'Tally', 'Tonex', 'TOP', 'Toshiba', 'Utax', 'V7', 'Xerox', 'Zebra'],
#       dtype=object)

# %%
file_path=r"/kaggle/input/stp-dataset/TOPUS_STOCKLIST_DGF (2).csv"
# Liste des encodages à essayer
encodings = ['utf-8', 'ISO-8859-1', 'latin1']

for encoding in encodings:
    try:
        # Tente de lire le fichier CSV avec l'encodage spécifié et un point-virgule comme séparateur
        df9= pd.read_csv(file_path, encoding=encoding, sep=',', on_bad_lines='skip', engine='python')
        print(f"File successfully loaded with {encoding} encoding.")
        break  # Si le fichier est lu avec succès, sortir de la boucle
    except FileNotFoundError:
        print("Error: File not found at", file_path)
        break  # Si le fichier n'est pas trouvé, sortir de la boucle
    except UnicodeDecodeError as e:
        print(f"Error with {encoding} encoding:", e)
    except Exception as e:
        print("Error:", e)

# Vérifiez si le DataFrame a été créé avec succès
if 'df9' in locals():
    print(df9.info())
else:
    print("Failed to load the file with the provided encodings.")
# Out:
# File successfully loaded with utf-8 encoding.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4142 entries, 0 to 4141
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sekcja       4142 non-null   object
#  1   Part_number  4142 non-null   object
#  2   Nazwa        4142 non-null   object
#  3   EAN          4142 non-null   object
#  4   Stan         4142 non-null   int64
#  5   Cena         4142 non-null   object
#  6   Waluta       4142 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 226.6+ KB
# None

# %%
new_column_names = ['Section',      
    'Part_number',  
   'description' ,       
   'EAN'    ,     
   'stock'   ,      
   'Prix'  ,       
   'Devise']
if len(df9.columns) == len(new_column_names):
                df9.columns = new_column_names
df9.columns
# Out:
# Index(['Section', 'Part_number', 'description', 'EAN', 'stock', 'Prix',
#        'Devise'],
#       dtype='object')

# %%
# Appliquer la fonction à la colonne 'Prix'
df9['Prix'] = df9['Prix'].apply(clean_price)

# %%
df9= df9[["Part_number","Section","description",'stock','Prix']]
old_names = ["Part_number","Section","description",'stock','Prix']
columns_rename=['Ref_produit','Categorie','Description','Quantite','Prix']
# Crée un dictionnaire de renommage
rename_dict = dict(zip(old_names, columns_rename))
df9= df9.rename(columns=rename_dict)
df9.head(3)
# Out:
#   Ref_produit         Categorie                 Description  Quantite  Prix
# 0      TN2000  Brother Supplies  Brother Toner Black TN2000         0  52.5
# 1      TN2220  Brother Supplies  Brother Toner Black TN2220         0  49.7
# 2      TN6600  Brother Supplies  Brother Toner Black TN6600        23  38.9

# %%
# Extraction du premier mot de la Categorie pour la colonne "Marque"
df9['Marque'] = df9['Categorie'].apply(lambda x: x.split()[0] if pd.notna(x) else 'Inconnu')

# %%
df9
# Out:
#      Ref_produit         Categorie  \
# 0         TN2000  Brother Supplies
# 1         TN2220  Brother Supplies
# 2         TN6600  Brother Supplies
# 3         TN3480  Brother Supplies
# 4         DR6000  Brother Supplies
# ...          ...               ...
# 4137   116R00036    Xerox Supplies
# 4138   116R00037    Xerox Supplies
# 4139   116R00035    Xerox Supplies
# 4140   115R00161    Xerox Supplies
# 4141   108R01471    Xerox Supplies
#
#                                           Description  Quantite   Prix  \
# 0                          Brother Toner Black TN2000         0   52.5
# 1                          Brother Toner Black TN2220         0   49.7
# 2                          Brother Toner Black TN6600        23   38.9
# 3                          Brother Toner Black TN3480       100   96.3
# 4                           Brother Drum Black DR6000         4   59.9
# ...                                               ...       ...    ...
# 4137         VersaLink B625 Transfer Roller 116R00036         0   23.7
# 4138  VersaLink B625 Bypass Tray Roller Kit 116R00037         0   25.2
# 4139   VersaLink B625 Paper Feed Roller Kit 116R00035         0   25.2
# 4140             VersaLink B620 Fuser 220 V 115R00161         0  332.5
# 4141  Phaser 3330 WC 33xx  Tray 2 Feed Roll 108R01471         0   27.3
#
#        Marque
# 0     Brother
# 1     Brother
# 2     Brother
# 3     Brother
# 4     Brother
# ...       ...
# 4137    Xerox
# 4138    Xerox
# 4139    Xerox
# 4140    Xerox
# 4141    Xerox
#
# [4142 rows x 6 columns]

# %%
file_path=r"/kaggle/input/stp-dataset/argor10072024 (1).csv"
# Liste des encodages à essayer
encodings = ['utf-8', 'ISO-8859-1', 'latin1']

for encoding in encodings:
    try:
        # Tente de lire le fichier CSV avec l'encodage spécifié et un point-virgule comme séparateur
        df10= pd.read_csv(file_path, encoding=encoding, sep=',', on_bad_lines='skip', engine='python')
        print(f"File successfully loaded with {encoding} encoding.")
        break  # Si le fichier est lu avec succès, sortir de la boucle
    except FileNotFoundError:
        print("Error: File not found at", file_path)
        break  # Si le fichier n'est pas trouvé, sortir de la boucle
    except UnicodeDecodeError as e:
        print(f"Error with {encoding} encoding:", e)
    except Exception as e:
        print("Error:", e)

# Vérifiez si le DataFrame a été créé avec succès
if 'df10' in locals():
    print(df10.info())
else:
    print("Failed to load the file with the provided encodings.")
# Out:
# File successfully loaded with utf-8 encoding.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 565 entries, 0 to 564
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  564 non-null    float64
#  1   Unnamed: 1  564 non-null    object
#  2   Unnamed: 2  564 non-null    object
#  3   Unnamed: 3  564 non-null    object
#  4   Unnamed: 4  564 non-null    float64
#  5   Unnamed: 5  564 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 26.6+ KB
# None

# %%
df10= df10[["Unnamed: 3","Unnamed: 2","Unnamed: 5"]]
old_names = ["Unnamed: 3","Unnamed: 2","Unnamed: 5"]
columns_rename=['Ref_produit','Description','Prix']
# Crée un dictionnaire de renommage
rename_dict = dict(zip(old_names, columns_rename))
df10 = df10.rename(columns=rename_dict)
df10.head(3)
# Out:
#   Ref_produit       Description    Prix
# 0     TN-3512   Brother TN-3512  111.18
# 1     TN-3520   Brother TN-3520  134.64
# 2    TN-910 C  Brother TN-910 C  207.06

# %%
# Extraction du premier mot de la Categorie pour la colonne "Marque"
df10['Marque'] = df10['Description'].apply(lambda x: x.split()[0] if pd.notna(x) else 'Inconnu')

# %%
df10
# Out:
#     Ref_produit       Description    Prix   Marque
# 0       TN-3512   Brother TN-3512  111.18  Brother
# 1       TN-3520   Brother TN-3520  134.64  Brother
# 2      TN-910 C  Brother TN-910 C  207.06  Brother
# 3      TN-910 M  Brother TN-910 M  207.06  Brother
# 4      TN-910 Y  Brother TN-910 Y  207.06  Brother
# ..          ...               ...     ...      ...
# 560   006R01518   Xerox 006R01518   78.54    Xerox
# 561   006R01519   Xerox 006R01519   78.54    Xerox
# 562   106R02310   Xerox 106R02310  103.02    Xerox
# 563   106R02773   Xerox 106R02773   48.96    Xerox
# 564         NaN               NaN     NaN  Inconnu
#
# [565 rows x 4 columns]

# %%
file_path=r"/kaggle/input/stp-dataset/axro.csv"
# Liste des encodages à essayer
encodings = ['utf-8', 'ISO-8859-1', 'latin1']

for encoding in encodings:
    try:
        # Tente de lire le fichier CSV avec l'encodage spécifié et un point-virgule comme séparateur
        df11= pd.read_csv(file_path, encoding=encoding, sep=';', on_bad_lines='skip', engine='python')
        print(f"File successfully loaded with {encoding} encoding.")
        break  # Si le fichier est lu avec succès, sortir de la boucle
    except FileNotFoundError:
        print("Error: File not found at", file_path)
        break  # Si le fichier n'est pas trouvé, sortir de la boucle
    except UnicodeDecodeError as e:
        print(f"Error with {encoding} encoding:", e)
    except Exception as e:
        print("Error:", e)

# Vérifiez si le DataFrame a été créé avec succès
if 'df11' in locals():
    print(df11.info())
else:
    print("Failed to load the file with the provided encodings.")
# Out:
# Error: No columns to parse from file
# Error: No columns to parse from file
# Error: No columns to parse from file
# Failed to load the file with the provided encodings.

# %%
file_path=r"/kaggle/input/stp-dataset/cid_export_04072023.csv"
# Liste des encodages à essayer
encodings = ['utf-8', 'ISO-8859-1', 'latin1']

for encoding in encodings:
    try:
        # Tente de lire le fichier CSV avec l'encodage spécifié et un point-virgule comme séparateur
        df12= pd.read_csv(file_path, encoding=encoding, sep=';', on_bad_lines='skip', engine='python')
        print(f"File successfully loaded with {encoding} encoding.")
        break  # Si le fichier est lu avec succès, sortir de la boucle
    except FileNotFoundError:
        print("Error: File not found at", file_path)
        break  # Si le fichier n'est pas trouvé, sortir de la boucle
    except UnicodeDecodeError as e:
        print(f"Error with {encoding} encoding:", e)
    except Exception as e:
        print("Error:", e)

# Vérifiez si le DataFrame a été créé avec succès
if 'df12' in locals():
    print(df12.info())
else:
    print("Failed to load the file with the provided encodings.")
# Out:
# Error with utf-8 encoding: 'utf-8' codec can't decode byte 0x87 in position 916: invalid start byte
# File successfully loaded with ISO-8859-1 encoding.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 922 entries, 0 to 921
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Code article             730 non-null    object
#  1   Marque                   730 non-null    object
#  2   Description commerciale  730 non-null    object
#  3    stock                   730 non-null    object
#  4    PV HT
# ? HT              730 non-null    object
#  5   Unnamed: 5               0 non-null      float64
#  6   Unnamed: 6               0 non-null      float64
#  7   Unnamed: 7               0 non-null      float64
#  8   Unnamed: 8               0 non-null      float64
#  9   Unnamed: 9               0 non-null      float64
#  10  Unnamed: 10              0 non-null      float64
#  11  Unnamed: 11              0 non-null      float64
#  12  Unnamed: 12              0 non-null      float64
#  13  Unnamed: 13              0 non-null      float64
#  14  Unnamed: 14              0 non-null      float64
#  15  Unnamed: 15              0 non-null      float64
#  16  Unnamed: 16              0 non-null      float64
#  17  Unnamed: 17              0 non-null      float64
#  18  Unnamed: 18              0 non-null      float64
#  19  Unnamed: 19              0 non-null      float64
# dtypes: float64(15), object(5)
# memory usage: 144.2+ KB
# None

# %%
columns_to_drop = ['Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19']
df12 = df12.drop(columns=columns_to_drop)

# %%
df12.columns
# Out:
# Index(['Code article', 'Marque', 'Description commerciale', ' stock ',
#        ' PV HT\n? HT '],
#       dtype='object')

# %%
df12= df12[["Code article","Marque","Description commerciale"," stock "," PV HT\n? HT "]]
old_names = ["Code article","Marque","Description commerciale"," stock "," PV HT\n? HT "]
columns_rename=['Ref_produit','Marque','Description','Quantite','Prix']
# Crée un dictionnaire de renommage
rename_dict = dict(zip(old_names, columns_rename))
df12 = df12.rename(columns=rename_dict)
df12.head(3)
# Out:
#   Ref_produit Marque                                        Description  \
# 0   265A9ET_N     HP  HP 125 Souris filaire USB noir pour HP Z1 G8; ...
# 1   H3T50AA_N     HP  HP X4000B Souris laser sans fil Bluetooth pour...
# 2   L2X04AA_N     HP  HP Adaptateur secteur CA 100-240 V 65 Watt PFC...
#
#   Quantite       Prix
# 0   662       5,50 ?
# 1   364      15,00 ?
# 2   260       9,00 ?

# %%
df12['Prix']=df12['Prix'].apply(clean_price)
df12.head(2)
# Out:
#   Ref_produit Marque                                        Description  \
# 0   265A9ET_N     HP  HP 125 Souris filaire USB noir pour HP Z1 G8; ...
# 1   H3T50AA_N     HP  HP X4000B Souris laser sans fil Bluetooth pour...
#
#   Quantite  Prix
# 0   662      5.5
# 1   364     15.0

# %%
file_path=r"/kaggle/input/stp-dataset/dexxon (1).csv"
# Liste des encodages à essayer
encodings = ['utf-8', 'ISO-8859-1', 'latin1']

for encoding in encodings:
    try:
        # Tente de lire le fichier CSV avec l'encodage spécifié et un point-virgule comme séparateur
        df13= pd.read_csv(file_path, encoding=encoding, sep=';', on_bad_lines='skip', engine='python')
        print(f"File successfully loaded with {encoding} encoding.")
        break  # Si le fichier est lu avec succès, sortir de la boucle
    except FileNotFoundError:
        print("Error: File not found at", file_path)
        break  # Si le fichier n'est pas trouvé, sortir de la boucle
    except UnicodeDecodeError as e:
        print(f"Error with {encoding} encoding:", e)
    except Exception as e:
        print("Error:", e)

# Vérifiez si le DataFrame a été créé avec succès
if 'df13' in locals():
    print(df13.info())
else:
    print("Failed to load the file with the provided encodings.")
# Out:
# Error with utf-8 encoding: 'utf-8' codec can't decode byte 0xe0 in position 1711: invalid continuation byte
# File successfully loaded with ISO-8859-1 encoding.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15351 entries, 0 to 15350
# Data columns (total 17 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Code article Dexxon                               15351 non-null  object
#  1   Code EAN                                          5179 non-null   float64
#  2   Description courte de l'article                   15351 non-null  object
#  3   PN Constructeur                                   15348 non-null  object
#  4   Nom du Fabricant                                  15351 non-null  object
#  5   Prix                                              15351 non-null  object
#  6   Redevance Sorecop                                 15351 non-null  object
#  7   Eco-taxe                                          15351 non-null  object
#  8   QtÃ© disponible                                   15351 non-null  int64
#  9   UnitÃ© de conditionnement                         15351 non-null  object
#  10  Facteur de conversion (par rapport Ã  la piÃ¨ce)  15351 non-null  int64
#  11  Poids brut                                        15351 non-null  object
#  12  Poids net                                         15351 non-null  object
#  13  UnitÃ© de poids                                   15351 non-null  object
#  14  HiÃ©rarchie article Niveau 1                      15351 non-null  object
#  15  Niveau 2                                          15348 non-null  object
#  16  Niveau 3                                          15265 non-null  object
# dtypes: float64(1), int64(2), object(14)
# memory usage: 2.0+ MB
# None

# %%
df13.head(3)
# Out:
#   Code article Dexxon      Code EAN           Description courte de l'article  \
# 0  000000000000006291           NaN       FM2-5535-000 SHUTTER DRIVE ASSEMBLY
# 1  000000000000006374           NaN  FM4-2531-000 PEDESTAL CONTROLLER PCB ASS
# 2        BFHDD1000LSM  5.060126e+12   Buffalo LinkStation Mini 1TB DLNA White
#
#   PN Constructeur Nom du Fabricant    Prix Redevance Sorecop Eco-taxe  \
# 0    FM2-5535-000            Canon   49,82              0,00     0,00
# 1    FM4-2531-000            Canon   29,28              0,00     0,00
# 2  LS-WS1.0TGL/R1          Buffalo  149,48              0,00     0,00
#
#    QtÃ© disponible UnitÃ© de conditionnement  \
# 0                0                        ST
# 1                0                        ST
# 2                5                        ST
#
#    Facteur de conversion (par rapport Ã  la piÃ¨ce) Poids brut Poids net  \
# 0                                                 1       0,03      0,00
# 1                                                 1       0,30      0,00
# 2                                                 1       0,95      0,50
#
#   UnitÃ© de poids HiÃ©rarchie article Niveau 1         Niveau 2  \
# 0              KG                  Bureautique      Accessoires
# 1              KG                  Bureautique      Accessoires
# 2              KG                     Stockage  HDD et cles USB
#
#            Niveau 3
# 0  Pieces detachees
# 1  Pieces detachees
# 2               HDD

# %%
df13= df13[["PN Constructeur","Niveau 2",'Nom du Fabricant',"Description courte de l'article",'QtÃ© disponible', 'Prix']]
old_names = ["PN Constructeur","Niveau 2",'Nom du Fabricant',"Description courte de l'article",'QtÃ© disponible', 'Prix']
columns_rename=['Ref_produit','Categorie','Marque','Description','Quantite','Prix']
# Crée un dictionnaire de renommage
rename_dict = dict(zip(old_names, columns_rename))
df13 = df13.rename(columns=rename_dict)
df13.head(4)
# Out:
#       Ref_produit           Categorie   Marque  \
# 0    FM2-5535-000         Accessoires    Canon
# 1    FM4-2531-000         Accessoires    Canon
# 2  LS-WS1.0TGL/R1     HDD et cles USB  Buffalo
# 3     T4MP-N-P-45  Solutions Services       DS
#
#                                 Description  Quantite    Prix
# 0       FM2-5535-000 SHUTTER DRIVE ASSEMBLY         0   49,82
# 1  FM4-2531-000 PEDESTAL CONTROLLER PCB ASS         0   29,28
# 2   Buffalo LinkStation Mini 1TB DLNA White         5  149,48
# 3       Bluemega Lecteur de badge universel         0  139,91

# %%
df13['Fournisseur'] = 'Dexxon'
df13.head()
# Out:
#       Ref_produit           Categorie   Marque  \
# 0    FM2-5535-000         Accessoires    Canon
# 1    FM4-2531-000         Accessoires    Canon
# 2  LS-WS1.0TGL/R1     HDD et cles USB  Buffalo
# 3     T4MP-N-P-45  Solutions Services       DS
# 4          BAE001              Divers  Brother
#
#                                 Description  Quantite    Prix Fournisseur
# 0       FM2-5535-000 SHUTTER DRIVE ASSEMBLY         0   49,82      Dexxon
# 1  FM4-2531-000 PEDESTAL CONTROLLER PCB ASS         0   29,28      Dexxon
# 2   Buffalo LinkStation Mini 1TB DLNA White         5  149,48      Dexxon
# 3       Bluemega Lecteur de badge universel         0  139,91      Dexxon
# 4             Brother Batterie Rechargeable        10   17,37      Dexxon

# %%
file_path=r"/kaggle/input/stp-dataset/eparts.csv"
# Liste des encodages à essayer
encodings = ['utf-8', 'ISO-8859-1', 'latin1']

for encoding in encodings:
    try:
        # Tente de lire le fichier CSV avec l'encodage spécifié et un point-virgule comme séparateur
        df14= pd.read_csv(file_path, encoding=encoding, sep=';', on_bad_lines='skip', engine='python')
        print(f"File successfully loaded with {encoding} encoding.")
        break  # Si le fichier est lu avec succès, sortir de la boucle
    except FileNotFoundError:
        print("Error: File not found at", file_path)
        break  # Si le fichier n'est pas trouvé, sortir de la boucle
    except UnicodeDecodeError as e:
        print(f"Error with {encoding} encoding:", e)
    except Exception as e:
        print("Error:", e)

# Vérifiez si le DataFrame a été créé avec succès
if 'df14' in locals():
    print(df14.info())
else:
    print("Failed to load the file with the provided encodings.")
# Out:
# File successfully loaded with utf-8 encoding.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155037 entries, 0 to 155036
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   reference         155037 non-null  object
#  1   client-reference  0 non-null       float64
#  2   presentation1     155036 non-null  object
#  3   presentation2     1070 non-null    object
#  4   brand             154799 non-null  object
#  5   stock             155037 non-null  int64
#  6   client-price      155037 non-null  object
#  7   available-date    155036 non-null  object
#  8   EAN               621 non-null     object
#  9   picture           3604 non-null    object
#  10  related-printer   4077 non-null    object
#  11  type-produit      4077 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 14.2+ MB
# None

# %%
df14
# Out:
#              reference  client-reference  \
# 0             RG5-6533               NaN
# 1             RG5-7061               NaN
# 2             RG5-4111               NaN
# 3             RG5-5569               NaN
# 4          C9153-67908               NaN
# ...                ...               ...
# 155032        X950X2MG               NaN
# 155033        X950X2YG               NaN
# 155034  1702MS8NLV-GEN               NaN
# 155035         CF280JC               NaN
# 155036          CZ129A               NaN
#
#                                    presentation1 presentation2    brand  \
# 0            YOU CAN ORDER MAINTENANCE KIT C3915           NaN    HPinc
# 1                       FUSER ORIGINAL HP LJ5100           NaN    HPinc
# 2                    FUSER UNIT ORIGINAL HP LJ6P           NaN    HPinc
# 3                            FUSER LJ2200 NEW HP           NaN    CANON
# 4                         FUSER UNIT ORIGINAL HP           NaN    HPinc
# ...                                          ...           ...      ...
# 155032    TONER X950/X952 (24.000 Sheet) MAGENTO           NaN  KYOCERA
# 155033     TONER X950/X952 (24.000 Sheet) YELLOW           NaN  KYOCERA
# 155034           MK FS-2100D / FS-2100DN GENERIC       MK-3100  GENERIC
# 155035  TONER CARTRIDGE JUMBO 80X BLACK CONTRACT  10 000 pages    HPinc
# 155036                      INK CARTRIDGE NO 711           NaN      CET
#
#         stock client-price available-date            EAN  \
# 0           0       189,00      7-10 days  5705965552711
# 1           2       155,00       En stock  5705965639566
# 2           0        65,00      7-10 days  5712505412664
# 3          12        72,00       En stock  5704327956099
# 4           0       405,00      7-10 days            NaN
# ...       ...          ...            ...            ...
# 155032      0       332,48       5-7 days            NaN
# 155033      0       332,48       5-7 days            NaN
# 155034      1       100,00       En stock            NaN
# 155035      0        89,00       5-7 days            NaN
# 155036      0        54,61       5-7 days            NaN
#
#                                                   picture  \
# 0       http://www.eparts.fr/eparts/CustomUpload/374O3...
# 1       http://www.eparts.fr/eparts/CustomUpload/374O3...
# 2       http://www.eparts.fr/eparts/CustomUpload/374O3...
# 3       http://www.eparts.fr/eparts/CustomUpload/374O3...
# 4       http://www.eparts.fr/eparts/CustomUpload/374O3...
# ...                                                   ...
# 155032                                                NaN
# 155033                                                NaN
# 155034                                                NaN
# 155035  http://www.eparts.fr/eparts/CustomUpload/374O3...
# 155036                                                NaN
#
#                                       related-printer     type-produit
# 0                                    LJ 8100, LJ 8150       FUSER UNIT
# 1                                             LJ 5100       FUSER UNIT
# 2                                                 NaN              NaN
# 3                                             LJ 2200       FUSER UNIT
# 4       LJ 9000, LJ 9050, LJ 9040, LJ M9040, LJ M9050       FUSER UNIT
# ...                                               ...              ...
# 155032                                            NaN              NaN
# 155033                                            NaN              NaN
# 155034                                        FS-2100  MAINTENANCE KIT
# 155035                               LJ M401, LJ M425       CONSUMABLE
# 155036                                            NaN              NaN
#
# [155037 rows x 12 columns]

# %%
df14= df14[["reference","type-produit",'brand',"presentation1",'stock', 'client-price']]
old_names = ["reference","type-produit",'brand',"presentation1",'stock', 'client-price']
columns_rename=['Ref_produit','Categorie','Marque','Description','Quantite','Prix']
# Crée un dictionnaire de renommage
rename_dict = dict(zip(old_names, columns_rename))
df14 = df14.rename(columns=rename_dict)
df14.head(3)
# Out:
#   Ref_produit   Categorie Marque                          Description  \
# 0    RG5-6533  FUSER UNIT  HPinc  YOU CAN ORDER MAINTENANCE KIT C3915
# 1    RG5-7061  FUSER UNIT  HPinc             FUSER ORIGINAL HP LJ5100
# 2    RG5-4111         NaN  HPinc          FUSER UNIT ORIGINAL HP LJ6P
#
#    Quantite    Prix
# 0         0  189,00
# 1         2  155,00
# 2         0   65,00

# %%
file_path=r"/kaggle/input/stp-dataset/imcopex.csv"
# Liste des encodages à essayer
encodings = ['utf-8', 'ISO-8859-1', 'latin1']

for encoding in encodings:
    try:
        # Tente de lire le fichier CSV avec l'encodage spécifié et un point-virgule comme séparateur
        df15= pd.read_csv(file_path, encoding=encoding, sep=';', on_bad_lines='skip', engine='python')
        print(f"File successfully loaded with {encoding} encoding.")
        break  # Si le fichier est lu avec succès, sortir de la boucle
    except FileNotFoundError:
        print("Error: File not found at", file_path)
        break  # Si le fichier n'est pas trouvé, sortir de la boucle
    except UnicodeDecodeError as e:
        print(f"Error with {encoding} encoding:", e)
    except Exception as e:
        print("Error:", e)

# Vérifiez si le DataFrame a été créé avec succès
if 'df15' in locals():
    print(df15.info())
else:
    print("Failed to load the file with the provided encodings.")
# Out:
# File successfully loaded with utf-8 encoding.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3407 entries, 0 to 3406
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Manufacturer             3407 non-null   object
#  1   OEM No.                  3407 non-null   object
#  2   Item group               3407 non-null   object
#  3   imcopex Product details  3407 non-null   object
#  4   Price                    3407 non-null   object
#  5   free stock               3407 non-null   int64
#  6   EAN No.                  3271 non-null   float64
#  7   Pallet Goods             3407 non-null   int64
#  8   Customs Tariff number    1883 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 239.7+ KB
# None

# %%
df15
# Out:
#      Manufacturer              OEM No.          Item group  \
# 0             AMD     100-100000510BOX                CPUs
# 1             AMD     100-100000031BOX                CPUs
# 2             AMD     100-100001489BOX                CPUs
# 3             AMD     100-100001488BOX                CPUs
# 4             AMD     100-100000065BOX                CPUs
# ...           ...                  ...                 ...
# 3402     Zwilling          71030-000-0  Household & Garden
# 3403     Zwilling          66460-000-0  Household & Garden
# 3404        Zyxel  GS2220-28HP-EU0101F   Network Equipment
# 3405        Zyxel  GS2220-50HP-EU0101F   Network Equipment
# 3406        Zyxel   XGS2220-30-EU0101F   Network Equipment
#
#                                 imcopex Product details   Price  free stock  \
# 0     AMD Ryzen 3 4100 3 8 AMD8 AMD 8 GHz (100-10000...   49,00          10
# 1     AMD Ryzen 5 3600 3 6 AMD6 AMD 6 GHz (100-10000...   65,72          15
# 2     AMD Ryzen 5 5500GT 3 6 AMD6 AMD 6 GHz (100-100...   87,69          69
# 3     AMD Ryzen 5 5600GT 3 6 AMD6 AMD 6 GHz (100-100...  108,46          20
# 4     AMD Ryzen 5 5600X 3 7 AMD7 AMD 7 GHz (100-1000...  104,29          47
# ...                                                 ...     ...         ...
# 3402  Zwilling Flow Saucepan-Set SaucepanSet 5pcs st...  106,90          29
# 3403  Zwilling Vitality Saucepan-Set SaucepanSet 5pc...  108,90          20
# 3404  ZyXEL Switch GS2220-28HP-EU0101F GS222028HPEU0...  435,42           2
# 3405  ZyXEL Switch GS2220-50HP-EU0101F GS222050HPEU0...  523,12           1
# 3406  Zyxel Switch XGS2220-30-EU0101F XGS222030EU010...  422,92           6
#
#            EAN No.  Pallet Goods  Customs Tariff number
# 0     7.301433e+11             0             84733080.0
# 1     7.301433e+11             0                    NaN
# 2     7.301433e+11             0             84733020.0
# 3     7.301433e+11             0             84733020.0
# 4     7.301433e+11             0             84733080.0
# ...            ...           ...                    ...
# 3402  4.009840e+12             0                    NaN
# 3403  4.009839e+12             0                    NaN
# 3404  4.718938e+12             0             85176200.0
# 3405  4.718938e+12             0             85176200.0
# 3406  4.718938e+12             0             85176200.0
#
# [3407 rows x 9 columns]

# %%
df15['Fournisseur'] ='imcopex'
df15= df15[["OEM No.",'Manufacturer',"imcopex Product details",'free stock', 'Customs Tariff number']]
old_names = ["OEM No.",'Manufacturer',"imcopex Product details",'free stock', 'Customs Tariff number']
columns_rename=['Ref_produit','Marque','Description','Quantite','Prix']
# Crée un dictionnaire de renommage
rename_dict = dict(zip(old_names, columns_rename))
df15 = df15.rename(columns=rename_dict)
df15.head(3)
# Out:
#         Ref_produit Marque                                        Description  \
# 0  100-100000510BOX    AMD  AMD Ryzen 3 4100 3 8 AMD8 AMD 8 GHz (100-10000...
# 1  100-100000031BOX    AMD  AMD Ryzen 5 3600 3 6 AMD6 AMD 6 GHz (100-10000...
# 2  100-100001489BOX    AMD  AMD Ryzen 5 5500GT 3 6 AMD6 AMD 6 GHz (100-100...
#
#    Quantite        Prix
# 0        10  84733080.0
# 1        15         NaN
# 2        69  84733020.0

# %%
file_path=r"/kaggle/input/stp-dataset/tarox (1).csv"
# Liste des encodages à essayer
encodings = ['utf-8', 'ISO-8859-1', 'latin1']

for encoding in encodings:
    try:
        # Tente de lire le fichier CSV avec l'encodage spécifié et un point-virgule comme séparateur
        df16= pd.read_csv(file_path, encoding=encoding, sep=';', on_bad_lines='skip', engine='python')
        print(f"File successfully loaded with {encoding} encoding.")
        break  # Si le fichier est lu avec succès, sortir de la boucle
    except FileNotFoundError:
        print("Error: File not found at", file_path)
        break  # Si le fichier n'est pas trouvé, sortir de la boucle
    except UnicodeDecodeError as e:
        print(f"Error with {encoding} encoding:", e)
    except Exception as e:
        print("Error:", e)

# Vérifiez si le DataFrame a été créé avec succès
if 'df16' in locals():
    print(df16.info())
else:
    print("Failed to load the file with the provided encodings.")
# Out:
# Error with utf-8 encoding: 'utf-8' codec can't decode byte 0xf6 in position 684: invalid start byte
# File successfully loaded with ISO-8859-1 encoding.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17340 entries, 0 to 17339
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ARCODE           17340 non-null  int64
#  1   PG1              17340 non-null  object
#  2   PG2              17340 non-null  object
#  3   PG3              14037 non-null  object
#  4   HerstellerKurz   17339 non-null  object
#  5   HerstellerArtNr  17340 non-null  object
#  6   Hersteller       17339 non-null  object
#  7   EAN              11752 non-null  float64
#  8   BezeichnungKurz  17340 non-null  object
#  9   Preis            17340 non-null  object
#  10  Bestand          17340 non-null  int64
#  11  Datenblatt       94 non-null     object
#  12  Bild             94 non-null     object
#  13  UVP              17340 non-null  object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.9+ MB
# None

# %%
df16= df16[["HerstellerArtNr","PG2",'Hersteller',"BezeichnungKurz",'HerstellerKurz','Bestand', 'Preis']]
old_names = ["HerstellerArtNr","PG2",'HerstellerKurz',"BezeichnungKurz",'Hersteller','Bestand', 'Preis']
columns_rename=['Ref_produit','Categorie','Marque','Description','Ref_fournisseur','Quantite','Prix']
# Crée un dictionnaire de renommage
rename_dict = dict(zip(old_names, columns_rename))
df16 = df16.rename(columns=rename_dict)
df16.head(3)
# Out:
#    Ref_produit            Categorie Ref_fournisseur  \
# 0  DES-1008D/E               Switch          D-Link
# 1  DES-1016D/E               Switch          D-Link
# 2        33344  Converter / Adapter          InLine
#
#                                          Description  Marque  Quantite   Prix
# 0  DLINK DES-1008D/E 8-Port Layer2 Fast Ethernet ...  D-Link         0   9,40
# 1  DLINK DES-1016D/E 16-Port Layer2 Fast Ethernet...  D-Link         0  35,49
# 2           InLine CPU ZB Adapter 3pin an 4pin 33344  InLine        17   0,84

# %%
file_path=r"/kaggle/input/stp-dataset/terra.csv"
# Liste des encodages à essayer
encodings = ['utf-8', 'ISO-8859-1', 'latin1']

for encoding in encodings:
    try:
        # Tente de lire le fichier CSV avec l'encodage spécifié et un point-virgule comme séparateur
        df17= pd.read_csv(file_path, encoding=encoding, sep=';', on_bad_lines='skip', engine='python')
        print(f"File successfully loaded with {encoding} encoding.")
        break  # Si le fichier est lu avec succès, sortir de la boucle
    except FileNotFoundError:
        print("Error: File not found at", file_path)
        break  # Si le fichier n'est pas trouvé, sortir de la boucle
    except UnicodeDecodeError as e:
        print(f"Error with {encoding} encoding:", e)
    except Exception as e:
        print("Error:", e)

# Vérifiez si le DataFrame a été créé avec succès
if 'df17' in locals():
    print(df17.info())
else:
    print("Failed to load the file with the provided encodings.")
# Out:
# File successfully loaded with utf-8 encoding.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11276 entries, 0 to 11275
# Data columns (total 47 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ProductId                         11276 non-null  object
#  1   ReferenceNo                       10963 non-null  object
#  2   EAN                               4432 non-null   float64
#  3   Manufacturer                      11275 non-null  object
#  4   Price_B2B_Regular                 11276 non-null  object
#  5   Price_B2B_Discounted              11276 non-null  object
#  6   Price_B2B_DiscountPercent         11276 non-null  int64
#  7   Price_B2B_DiscountAmount          11276 non-null  int64
#  8   Price_B2C_exclVAT                 11276 non-null  object
#  9   Price_B2C_inclVAT                 11276 non-null  object
#  10  Price_B2C_VATRate                 11276 non-null  int64
#  11  Price_B2C_VATCountry              11276 non-null  object
#  12  Price_B2X_Currency                11276 non-null  object
#  13  Stock                             11276 non-null  int64
#  14  StockNextDelivery                 773 non-null    object
#  15  StockNextDeliveryAccessVolume     11276 non-null  int64
#  16  WarrantyCode                      4984 non-null   object
#  17  EOL                               11276 non-null  int64
#  18  Promotion                         11276 non-null  int64
#  19  NonReturnable                     11276 non-null  int64
#  20  RemainingStock                    11276 non-null  int64
#  21  ImagePrimary                      284 non-null    object
#  22  ImageAdditional                   192 non-null    object
#  23  ProductLink                       0 non-null      float64
#  24  GrossWeight                       11276 non-null  object
#  25  NetWeight                         0 non-null      float64
#  26  RelatedProducts                   302 non-null    object
#  27  AccessoryProducts                 1123 non-null   object
#  28  Description_1031_German           11275 non-null  object
#  29  CategoryName_1031_German          11276 non-null  object
#  30  CategoryPath_1031_German          11276 non-null  object
#  31  WarrantyDescription_1031_German   4984 non-null   object
#  32  Description_1033_English          11275 non-null  object
#  33  CategoryName_1033_English         11276 non-null  object
#  34  CategoryPath_1033_English         11276 non-null  object
#  35  WarrantyDescription_1033_English  1969 non-null   object
#  36  Description_1036_French           11275 non-null  object
#  37  CategoryName_1036_French          11276 non-null  object
#  38  CategoryPath_1036_French          11276 non-null  object
#  39  WarrantyDescription_1036_French   3050 non-null   object
#  40  Description_1043_Dutch            11275 non-null  object
#  41  CategoryName_1043_Dutch           11276 non-null  object
#  42  CategoryPath_1043_Dutch           11276 non-null  object
#  43  WarrantyDescription_1043_Dutch    1906 non-null   object
#  44  ProductDisplayType                11276 non-null  object
#  45  LicenseTypeCode                   6218 non-null   object
#  46  LicenseTypeDescription            6217 non-null   object
# dtypes: float64(3), int64(9), object(35)
# memory usage: 4.0+ MB
# None

# %%
df17
# Out:
#       ProductId               ReferenceNo           EAN Manufacturer  \
# 0       6540032                 FQC-10526  8.898429e+11    Microsoft
# 1       6481251                 021-08709           NaN    Microsoft
# 2       3850730              FAN-12CM-T01  4.713214e+12         QNAP
# 3       3860412                   SG2218P  4.897099e+12      TP-LINK
# 4       5770037                   LC1000C  4.977767e+12      Brother
# ...         ...                       ...           ...          ...
# 11271   8001022              MK9540-77A38  5.052179e+12    Honeywell
# 11272   8001029           MK5145-31A38-EU  5.052179e+12    Honeywell
# 11273   2510380           90YV0GB2-M0NA10  4.711081e+12      Asustek
# 11274   5400380            LS34C650TAUXEN  8.806095e+12      Samsung
# 11275   1480375  TERRA MOBILE DOCKING 810  4.039407e+12  WORTMANN AG
#
#       Price_B2B_Regular Price_B2B_Discounted  Price_B2B_DiscountPercent  \
# 0                 130,9                130,9                          0
# 1                   122                  122                          0
# 2                  11,9                 11,9                          0
# 3                 204,5                204,5                          0
# 4                   9,3                  9,3                          0
# ...                 ...                  ...                        ...
# 11271              69,5                 69,5                          0
# 11272             42,53                42,53                          0
# 11273             245,9                245,9                          0
# 11274               445                  445                          0
# 11275               209                  209                          0
#
#        Price_B2B_DiscountAmount Price_B2C_exclVAT Price_B2C_inclVAT  ...  \
# 0                             0                 0                 0  ...
# 1                             0               138             165,6  ...
# 2                             0                 0                 0  ...
# 3                             0                 0                 0  ...
# 4                             0                 0                 0  ...
# ...                         ...               ...               ...  ...
# 11271                         0                 0                 0  ...
# 11272                         0                 0                 0  ...
# 11273                         0                 0                 0  ...
# 11274                         0            646,22            775,46  ...
# 11275                         0            293,27            351,92  ...
#
#             CategoryName_1036_French                 CategoryPath_1036_French  \
# 0            Systèmes d'exploitation        Logiciels|Systèmes d'exploitation
# 1                       Applications                   Logiciels|Applications
# 2             Accessoires du système       Accessoires|Accessoires du système
# 3      Concentrateurs & Commutateurs     Réseau|Concentrateurs & Commutateurs
# 4                       Consommables                             Consommables
# ...                              ...                                      ...
# 11271      Lecteurs de codes à barre  Périphériques|Lecteurs de codes à barre
# 11272      Lecteurs de codes à barre  Périphériques|Lecteurs de codes à barre
# 11273                   Cartes vidéo                             Cartes vidéo
# 11274                      Moniteurs                                Moniteurs
# 11275             Stations d'accueil                       Stations d'accueil
#
#             WarrantyDescription_1036_French  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3      60 mois garantie retour constructeur
# 4             6 mois service retour atelier
# ...                                     ...
# 11271                                   NaN
# 11272                                   NaN
# 11273        36 mois service retour atelier
# 11274  36 mois garantie retour constructeur
# 11275                                   NaN
#
#                                   Description_1043_Dutch  \
# 0                 MS SB Windows 11 Pro 64bit [DK] DVD+++
# 1                  MS OVL Office Std SA ADD 1Y1Y GOV [D]
# 2                    QNAP Gehäuselüfter +++ FAN-12CM-T01
# 3      TP-LINK Switch SG2218P 18xGBit/2xSFP Smart Man...
# 4                            Tinte Brother LC-1000C cyan
# ...                                                  ...
# 11271         Honeywell MS9540 Barcode Scanner USB beige
# 11272  Honeywell MS5145 Barcode Scanner Eclipse USB b...
# 11273  ASUS VGA 12GB RTX3060 DUAL-O12G-V2 3xDP/HDMI D...
# 11274  Samsung LCD S34C650TAU 34" white 21:9 ,3.440 x...
# 11275  TERRA MOBILE Dockingstation 810 USB-C/Triple 4...
#
#       CategoryName_1043_Dutch       CategoryPath_1043_Dutch  \
# 0          Operating systemen   Software|Operating systemen
# 1                toepassingen         Software|toepassingen
# 2           systeemtoebehoren  Toebehoren|systeemtoebehoren
# 3             Hubs & Switches       Netwerk|Hubs & Switches
# 4        Verbruikersartikelen          Verbruikersartikelen
# ...                       ...                           ...
# 11271           Barcode-lezer  Randapparatuur|Barcode-lezer
# 11272           Barcode-lezer  Randapparatuur|Barcode-lezer
# 11273       Grafische kaarten             Grafische kaarten
# 11274               Monitoren                     Monitoren
# 11275         Dockingstations               Dockingstations
#
#       WarrantyDescription_1043_Dutch  ProductDisplayType  LicenseTypeCode  \
# 0                                NaN      RegularProduct           MSCOEM
# 1                                NaN      RegularProduct             MSOV
# 2                                NaN      RegularProduct              NaN
# 3                                NaN      RegularProduct              NaN
# 4       6 Maanden service (bring in)      RegularProduct              NaN
# ...                              ...                 ...              ...
# 11271                            NaN      RegularProduct              NaN
# 11272                            NaN      RegularProduct              NaN
# 11273  36 Maanden service (bring in)      RegularProduct              NaN
# 11274                            NaN      RegularProduct              NaN
# 11275                            NaN      RegularProduct              NaN
#
#              LicenseTypeDescription
# 0      Microsoft System Builder/DSP
# 1              Microsoft Open Value
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 11271                           NaN
# 11272                           NaN
# 11273                           NaN
# 11274                           NaN
# 11275                           NaN
#
# [11276 rows x 47 columns]

# %%
matching_columns = {
    'ReferenceNo': 'Ref_produit',
    'CategoryName_1033_English':'Categorie',
    'Manufacturer': 'Marque',
    'Description_1033_English':'Description',
    'Stock': 'Quantite',
    'Price_B2B_Regular':'Prix'    
}
# Crée un dictionnaire de renommage
df17 = df17.rename(columns=matching_columns)
df17 = df17[['Ref_produit','Categorie','Marque','Description', 'Quantite', 'Prix']]
df17.head(3)
# Out:
#     Ref_produit           Categorie     Marque  \
# 0     FQC-10526   Operating Systems  Microsoft
# 1     021-08709        Applications  Microsoft
# 2  FAN-12CM-T01  System Accessories       QNAP
#
#                               Description  Quantite   Prix
# 0  MS SB Windows 11 Pro 64bit [DK] DVD+++         0  130,9
# 1   MS OVL Office Std SA ADD 1Y1Y GOV [D]       100    122
# 2     QNAP Gehäuselüfter +++ FAN-12CM-T01         0   11,9

# %%
file_path=r"/kaggle/input/stp-dataset/travion.csv"
# Liste des encodages à essayer
encodings = ['utf-8', 'ISO-8859-1', 'latin1']

for encoding in encodings:
    try:
        # Tente de lire le fichier CSV avec l'encodage spécifié et un point-virgule comme séparateur
        df18= pd.read_csv(file_path, encoding=encoding, sep=';', on_bad_lines='skip', engine='python')
        print(f"File successfully loaded with {encoding} encoding.")
        break  # Si le fichier est lu avec succès, sortir de la boucle
    except FileNotFoundError:
        print("Error: File not found at", file_path)
        break  # Si le fichier n'est pas trouvé, sortir de la boucle
    except UnicodeDecodeError as e:
        print(f"Error with {encoding} encoding:", e)
    except Exception as e:
        print("Error:", e)

# Vérifiez si le DataFrame a été créé avec succès
if 'df18' in locals():
    print(df18.info())
else:
    print("Failed to load the file with the provided encodings.")
# Out:
# Error with utf-8 encoding: 'utf-8' codec can't decode byte 0xe9 in position 164: invalid continuation byte
# File successfully loaded with ISO-8859-1 encoding.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3978 entries, 0 to 3977
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ARTICLENR          3978 non-null   object
#  1   OEMNR              3978 non-null   object
#  2   EANNR              3516 non-null   float64
#  3   UNSPSC             3978 non-null   int64
#  4   UNSPSCDESCRIPTION  3978 non-null   object
#  5   BRAND              3978 non-null   object
#  6   DESCRIPTION        3978 non-null   object
#  7   STOCK              3978 non-null   int64
#  8   Unnamed: 8         0 non-null      float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 279.8+ KB
# None

# %%
old_names = ["OEMNR", "UNSPSCDESCRIPTION", "BRAND", "DESCRIPTION", "STOCK"]
columns_rename = ['Ref_produit', 'Categorie', 'Marque', 'Description', 'Quantite']

# Créer un dictionnaire de renommage
rename_dict = dict(zip(old_names, columns_rename))

# Renommer les colonnes
df18 = df18.rename(columns=rename_dict)
df18=df18[['Ref_produit','Categorie', 'Marque', 'Description', 'Quantite']]
df18.head()
# Out:
#         Ref_produit               Categorie         Marque  \
# 0   C1000-16FP-2G-L  Commutateurs de réseau  CISCO SYSTEMS
# 1  C1000-16P-E-2G-L  Commutateurs de réseau  CISCO SYSTEMS
# 2  C1000-16T-E-2G-L  Commutateurs de réseau  CISCO SYSTEMS
# 3   C1000-24FP-4X-L  Commutateurs de réseau  CISCO SYSTEMS
# 4   C1000-48FP-4X-L  Commutateurs de réseau  CISCO SYSTEMS
#
#                                          Description  Quantite
# 0        Catalyst 1000 16port GE Full POE - 2x1G SFP         9
# 1  Catalyst 1000 16port GE - POE - Ext PS - 2x1G SFP         4
# 2        Catalyst 1000 16port GE - Ext PS - 2x1G SFP         1
# 3     Catalyst 1000 24port GE - Full POE - 4x10G SFP         3
# 4     Catalyst 1000 48port GE - Full POE - 4x10G SFP         2

# %%
df = pd.concat([df0[commun_columns], df2[commun_columns], df4[commun_columns], df6[commun_columns], df7[commun_columns], df12[commun_columns], df13[commun_columns], df14[commun_columns], df15[commun_columns], df16[commun_columns], df17[commun_columns], df18[commun_columns]])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1468890 entries, 0 to 3977
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Ref_produit  1468382 non-null  object
#  1   Marque       1468456 non-null  object
#  2   Description  1468646 non-null  object
# dtypes: object(3)
# memory usage: 44.8+ MB

# %%
df = pd.concat([df[commun_columns], df8[commun_columns], df9[commun_columns]])
df
# Out:
#        Ref_produit   Marque                                      Description
# 0          00PA474  2-Power                    Backlit Keyboard (Portuguese)
# 1          00PA556  2-Power                    Backlit Keyboard (Portuguese)
# 2     1200G-2USB-1  2-Power                    Voyager 1200g Barcode Scanner
# 3            1K2CF  2-Power                  Main Battery Pack 15.2V 3941mAh
# 4       207576-201  2-Power             Blackwire C5220 Stereo USB-A + 3.5mm
# ...            ...      ...                                              ...
# 4137     116R00036    Xerox         VersaLink B625 Transfer Roller 116R00036
# 4138     116R00037    Xerox  VersaLink B625 Bypass Tray Roller Kit 116R00037
# 4139     116R00035    Xerox   VersaLink B625 Paper Feed Roller Kit 116R00035
# 4140     115R00161    Xerox             VersaLink B620 Fuser 220 V 115R00161
# 4141     108R01471    Xerox  Phaser 3330 WC 33xx  Tray 2 Feed Roll 108R01471
#
# [1481267 rows x 3 columns]

# %%
df = pd.concat([df[commun_columns], df5[commun_columns]])

# %%
df = pd.concat([df[commun_columns], df10[commun_columns]])

# %%
df
# Out:
#       Ref_produit   Marque                           Description
# 0         00PA474  2-Power         Backlit Keyboard (Portuguese)
# 1         00PA556  2-Power         Backlit Keyboard (Portuguese)
# 2    1200G-2USB-1  2-Power         Voyager 1200g Barcode Scanner
# 3           1K2CF  2-Power       Main Battery Pack 15.2V 3941mAh
# 4      207576-201  2-Power  Blackwire C5220 Stereo USB-A + 3.5mm
# ..            ...      ...                                   ...
# 560     006R01518    Xerox                       Xerox 006R01518
# 561     006R01519    Xerox                       Xerox 006R01519
# 562     106R02310    Xerox                       Xerox 106R02310
# 563     106R02773    Xerox                       Xerox 106R02773
# 564           NaN  Inconnu                                   NaN
#
# [1518665 rows x 3 columns]

# %%
df = df.drop_duplicates(subset=['Ref_produit'])
df
# Out:
#          Ref_produit   Marque                           Description
# 0            00PA474  2-Power         Backlit Keyboard (Portuguese)
# 1            00PA556  2-Power         Backlit Keyboard (Portuguese)
# 2       1200G-2USB-1  2-Power         Voyager 1200g Barcode Scanner
# 3              1K2CF  2-Power       Main Battery Pack 15.2V 3941mAh
# 4         207576-201  2-Power  Blackwire C5220 Stereo USB-A + 3.5mm
# ..               ...      ...                                   ...
# 441           842341    Ricoh                   Ricoh Toner MP 2501
# 496           408216    Ricoh             Ricoh Toner SPC 352E Cyan
# 497           408218    Ricoh           Ricoh Toner SPC 352E Yellow
# 527         MX27GVSA    Sharp        Sharp MX27GVSA Developer C/M/Y
# 546  MX601B1/MX607B1    Sharp                 Sharp MX601B1/MX607B1
#
# [1438135 rows x 3 columns]

# %%
df.describe()
# Out:
#        Ref_produit   Marque Description
# count      1438134  1438035     1438082
# unique     1438134     1370      900693
# top        00PA474   Lenovo   BDPLANAR
# freq             1   214514        3748

# %%
rows_with_nulls = df[df.isnull().any(axis=1)]
rows_with_nulls
# Out:
#          Ref_produit                       Marque  \
# 165479    W126638174                       Ventev
# 165480    W126638175                       Ventev
# 165481    W126638176                       Ventev
# 165482    W126638177                       Ventev
# 269493    W126991623                       Lenovo
# ...              ...                          ...
# 154975       CE411AC                          NaN
# 155001      01221701                          NaN
# 155031       CE412AC                          NaN
# 11626    DS-D42B02-N                          NaN
# 1276    LNEX1L256GG4  Kioxia Holdings Corporation
#
#                                              Description
# 165479                                               NaN
# 165480                                               NaN
# 165481                                               NaN
# 165482                                               NaN
# 269493                                               NaN
# ...                                                  ...
# 154975                     HP CONTRACT Cartridge No.305A
# 155001                               OKI B930 IMAGE DRUM
# 155031                 HP 305A TONER YELLOW (2.600 Sheet
# 11626   HIK LED Wall Controller 1.3MP with 2x RJ45 Ports
# 1276                                                 NaN
#
# [152 rows x 3 columns]

# %%
df_concat_cleaned = df.dropna()

# %%
df_concat_cleaned
# Out:
#          Ref_produit   Marque                           Description
# 0            00PA474  2-Power         Backlit Keyboard (Portuguese)
# 1            00PA556  2-Power         Backlit Keyboard (Portuguese)
# 2       1200G-2USB-1  2-Power         Voyager 1200g Barcode Scanner
# 3              1K2CF  2-Power       Main Battery Pack 15.2V 3941mAh
# 4         207576-201  2-Power  Blackwire C5220 Stereo USB-A + 3.5mm
# ..               ...      ...                                   ...
# 441           842341    Ricoh                   Ricoh Toner MP 2501
# 496           408216    Ricoh             Ricoh Toner SPC 352E Cyan
# 497           408218    Ricoh           Ricoh Toner SPC 352E Yellow
# 527         MX27GVSA    Sharp        Sharp MX27GVSA Developer C/M/Y
# 546  MX601B1/MX607B1    Sharp                 Sharp MX601B1/MX607B1
#
# [1437983 rows x 3 columns]

# %%
Kdata=pd.read_csv('/kaggle/input/katia-data/Data1 (1).csv')

# %%
Kdata = Kdata[Kdata['Description'] != '0']

# %%
Kdata.describe()
# Out:
#        Ref_produit  Marque                      Description
# count       548702  548218                           541479
# unique      548702   10520                           399204
# top         US221A   APPLE  1YR SUBSCRIPTION WITH 1YR
# freq             1   57620                             1230

# %%
Kdata= Kdata.dropna()
Kdata.describe()
# Out:
#        Ref_produit  Marque                      Description
# count       541293  541293                           541293
# unique      541293   10467                           399028
# top         US221A   APPLE  1YR SUBSCRIPTION WITH 1YR
# freq             1   57619                             1230

# %%
Kdata
# Out:
#         Ref_produit          Marque  \
# 0            US221A            Aten
# 1       AEMNT00049A  Arctic Cooling
# 2       AEMNT00050A  Arctic Cooling
# 3       AEMNT00051A  Arctic Cooling
# 4        939-001644        Logitech
# ...             ...             ...
# 550990  zxp7ymckok2           ZEBRA
# 550991   zxp7ymcuvk           ZEBRA
# 550992      zxp9-16           ZEBRA
# 550993      zxplamt           ZEBRA
# 550994     zxplamt2           ZEBRA
#
#                                               Description
# 0       ATEN US-221 - USB peripheral sharing switch - ...
# 1                    ARCTIC Z1 Pro (Gen 3) - mounting kit
# 2                            ARCTIC Z2 Pro - mounting kit
# 3                    ARCTIC Z3 Pro (Gen 3) - mounting kit
# 4        Logitech Rally - video conferencing mounting kit
# ...                                                   ...
# 550990  Zebra ZXP 7 Series colour ribbon Zebra ZXP Ser...
# 550991  Zebra ZXP 7 Series colour ribbon Zebra ZXP Ser...
# 550992  Zebra ZXP Series 9, deux faces, 12 pts/mm (300...
# 550993  Zebra lamination ribbon Lamination ribbon, 1 m...
# 550994  Zebra lamination ribbon Lamination ribbon, 1 m...
#
# [541293 rows x 3 columns]

# %%
df = pd.concat([df[commun_columns], Kdata[commun_columns]])
df
# Out:
#          Ref_produit   Marque  \
# 0            00PA474  2-Power
# 1            00PA556  2-Power
# 2       1200G-2USB-1  2-Power
# 3              1K2CF  2-Power
# 4         207576-201  2-Power
# ...              ...      ...
# 550990   zxp7ymckok2    ZEBRA
# 550991    zxp7ymcuvk    ZEBRA
# 550992       zxp9-16    ZEBRA
# 550993       zxplamt    ZEBRA
# 550994      zxplamt2    ZEBRA
#
#                                               Description
# 0                           Backlit Keyboard (Portuguese)
# 1                           Backlit Keyboard (Portuguese)
# 2                           Voyager 1200g Barcode Scanner
# 3                         Main Battery Pack 15.2V 3941mAh
# 4                    Blackwire C5220 Stereo USB-A + 3.5mm
# ...                                                   ...
# 550990  Zebra ZXP 7 Series colour ribbon Zebra ZXP Ser...
# 550991  Zebra ZXP 7 Series colour ribbon Zebra ZXP Ser...
# 550992  Zebra ZXP Series 9, deux faces, 12 pts/mm (300...
# 550993  Zebra lamination ribbon Lamination ribbon, 1 m...
# 550994  Zebra lamination ribbon Lamination ribbon, 1 m...
#
# [1979428 rows x 3 columns]

# %%
df = df.drop_duplicates(subset=['Ref_produit'])
df
# Out:
#          Ref_produit   Marque  \
# 0            00PA474  2-Power
# 1            00PA556  2-Power
# 2       1200G-2USB-1  2-Power
# 3              1K2CF  2-Power
# 4         207576-201  2-Power
# ...              ...      ...
# 550990   zxp7ymckok2    ZEBRA
# 550991    zxp7ymcuvk    ZEBRA
# 550992       zxp9-16    ZEBRA
# 550993       zxplamt    ZEBRA
# 550994      zxplamt2    ZEBRA
#
#                                               Description
# 0                           Backlit Keyboard (Portuguese)
# 1                           Backlit Keyboard (Portuguese)
# 2                           Voyager 1200g Barcode Scanner
# 3                         Main Battery Pack 15.2V 3941mAh
# 4                    Blackwire C5220 Stereo USB-A + 3.5mm
# ...                                                   ...
# 550990  Zebra ZXP 7 Series colour ribbon Zebra ZXP Ser...
# 550991  Zebra ZXP 7 Series colour ribbon Zebra ZXP Ser...
# 550992  Zebra ZXP Series 9, deux faces, 12 pts/mm (300...
# 550993  Zebra lamination ribbon Lamination ribbon, 1 m...
# 550994  Zebra lamination ribbon Lamination ribbon, 1 m...
#
# [1873649 rows x 3 columns]

# %%
df.describe()
# Out:
#        Ref_produit   Marque Description
# count      1873648  1873549     1873596
# unique     1873648     4335     1206417
# top        00PA474   Lenovo   BDPLANAR
# freq             1   215457        3748

# %%
df.to_csv('clean_data.csv', index=False)

# %%
import pandas as pd
dfcat2=pd.read_csv('/kaggle/input/part2-icecat/132234_FR.csv')
dfcat2.info()
# Out:
# /tmp/ipykernel_19/3613939673.py:2: DtypeWarning: Columns (22,23,29,30,31,32,36,37,38,39,40,41,42,44,45,46,47,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfcat2=pd.read_csv('/kaggle/input/part2-icecat/132234_FR.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269782 entries, 0 to 269781
# Columns: 272 entries, Requested_prod_id to Specs 224
# dtypes: float64(6), int64(1), object(265)
# memory usage: 559.9+ MB

# %%
# Liste des colonnes à supprimer
columns_to_drop = [
    22, 23, 29, 30, 31, 32, 36, 37, 38, 39, 40, 41, 42, 44, 45, 46, 47,
    211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224,
    225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238,
    239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252,
    253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266,
    267, 268, 269, 270, 271
]

# Convertir les indices de colonnes en noms de colonnes
columns_to_drop = [dfcat2.columns[i] for i in columns_to_drop]

# Supprimer les colonnes
dfcat2.drop(columns=columns_to_drop, inplace=True)

# Afficher les informations sur le DataFrame
dfcat2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269782 entries, 0 to 269781
# Columns: 194 entries, Requested_prod_id to Specs 163
# dtypes: float64(6), int64(1), object(187)
# memory usage: 399.3+ MB

# %%
dfcat2.columns
# Out:
# Index(['Requested_prod_id', 'Requested_GTIN(EAN/UPC)', 'Requested_Icecat_id',
#        'ErrorMessage', 'Supplier', 'Prod_id', 'Icecat_id', 'GTIN(EAN/UPC)',
#        'Category', 'CatId',
#        ...
#        'Specs 154', 'Specs 155', 'Specs 156', 'Specs 157', 'Specs 158',
#        'Specs 159', 'Specs 160', 'Specs 161', 'Specs 162', 'Specs 163'],
#       dtype='object', length=194)

# %%
additional_columns_to_drop = [f'Specs {i}' for i in range(1, 164)]


# Combiner les deux listes de colonnes à supprimer
columns_to_drop.extend(additional_columns_to_drop)

# Vérifier l'existence des colonnes avant de les supprimer
columns_to_drop = [col for col in columns_to_drop if col in dfcat2.columns]

# Supprimer les colonnes
dfcat2.drop(columns=columns_to_drop, inplace=True)
dfcat2.head(3)
# Out:
#   Requested_prod_id  Requested_GTIN(EAN/UPC)  Requested_Icecat_id  \
# 0          T6208AAE                      NaN              4003037
# 1           VT122PA                      NaN              4003047
# 2           VT491AA                      NaN              4003049
#
#   ErrorMessage Supplier   Prod_id  Icecat_id GTIN(EAN/UPC)    Category  \
# 0          NaN       HP  T6208AAE  4003037.0           NaN  Non classé
# 1          NaN       HP   VT122PA  4003047.0           NaN     Laptops
# 2          NaN       HP   VT491AA  4003049.0           NaN    Claviers
#
#     CatId  ...                                           ThumbPic  \
# 0  1170.0  ...  http://images.icecat.biz/img/brand/thumb/1_cf8...
# 1   151.0  ...       https://images.icecat.biz/thumbs/3842217.jpg
# 2   194.0  ...       https://images.icecat.biz/thumbs/4003049.jpg
#
#                                         ProductTitle  \
# 0  HP BAC SLM for Business Process Monitor 200+ T...
# 1                              HP Mini 110-1101TU PC
# 2              HP VT491AA clavier Universel USB Noir
#
#                                            ShortDesc  \
# 0  HP BAC SLM for Business Process Monitor 200+ T...
# 1                                                NaN
# 2                                                NaN
#
#                              ShortSummaryDescription  \
# 0  HP BAC SLM for Business Process Monitor 200+ T...
# 1                              HP Mini 110-1101TU PC
# 2  HP VT491AA, Taille réelle (100 %), Avec fil, U...
#
#                               LongSummaryDescription  LongDesc  \
# 0  HP BAC SLM for Business Process Monitor 200+ T...       NaN
# 1                              HP Mini 110-1101TU PC       NaN
# 2  HP VT491AA. Facteur de forme du clavier: Taill...       NaN
#
#                                       ProductGallery  \
# 0  http://images.icecat.biz/img/brand/high/1_df42...
# 1  https://images.icecat.biz/img/norm/high/384221...
# 2  https://images.icecat.biz/img/norm/high/400304...
#
#   ProductGallery Resolution ProductGallery ExpirationDate ReasonsToBuy
# 0                   625x642                           NaN          NaN
# 1                 3300x3300                           NaN          NaN
# 2                   400x400                           NaN          NaN
#
# [3 rows x 31 columns]

# %%
dfcat2.columns
# Out:
# Index(['Requested_prod_id', 'Requested_GTIN(EAN/UPC)', 'Requested_Icecat_id',
#        'ErrorMessage', 'Supplier', 'Prod_id', 'Icecat_id', 'GTIN(EAN/UPC)',
#        'Category', 'CatId', 'ProductFamily', 'ProductSeries', 'Model',
#        'Updated', 'Quality', 'On_Market', 'Product_Views', 'HighPic',
#        'HighPic Resolution', 'LowPic', 'Pic500x500', 'ThumbPic',
#        'ProductTitle', 'ShortDesc', 'ShortSummaryDescription',
#        'LongSummaryDescription', 'LongDesc', 'ProductGallery',
#        'ProductGallery Resolution', 'ProductGallery ExpirationDate',
#        'ReasonsToBuy'],
#       dtype='object')

# %%
# Sélectionner uniquement les colonnes spécifiées
selected_columns = ['Requested_prod_id','Category', 'LongSummaryDescription', 'Supplier']

# Vérifier que les colonnes existent dans le DataFrame
selected_columns = [col for col in selected_columns if col in dfcat2.columns]

# Afficher les colonnes sélectionnées
dfcat2_selected = dfcat2[selected_columns]

# Afficher les informations et les premières lignes du DataFrame résultant
dfcat2_selected.info()
dfcat2_selected.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269782 entries, 0 to 269781
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Requested_prod_id       269782 non-null  object
#  1   Category                238251 non-null  object
#  2   LongSummaryDescription  238251 non-null  object
#  3   Supplier                269782 non-null  object
# dtypes: object(4)
# memory usage: 8.2+ MB
#   Requested_prod_id              Category  \
# 0          T6208AAE            Non classé
# 1           VT122PA               Laptops
# 2           VT491AA              Claviers
# 3           VV357PA               Laptops
# 4           FL963UT  PC/postes de travail
#
#                               LongSummaryDescription Supplier
# 0  HP BAC SLM for Business Process Monitor 200+ T...       HP
# 1                              HP Mini 110-1101TU PC       HP
# 2  HP VT491AA. Facteur de forme du clavier: Taill...       HP
# 3          HP Compaq Presario CQ61-318TX Notebook PC       HP
# 4                              HP xw4600 Workstation       HP

# %%
old_names = ['Requested_prod_id','Category', 'LongSummaryDescription', 'Supplier']
columns_rename = ['Ref_produit','Categorie', 'Description','Marque']

# Créer un dictionnaire de renommage
rename_dict = dict(zip(old_names, columns_rename))

# Renommer les colonnes
dfcat2_selected = dfcat2_selected.rename(columns=rename_dict)
#dfcat2_selected=dfcat2_selected['Ref_produit', 'Description','Marque']]
dfcat2_selected.head()
# Out:
#   Ref_produit             Categorie  \
# 0    T6208AAE            Non classé
# 1     VT122PA               Laptops
# 2     VT491AA              Claviers
# 3     VV357PA               Laptops
# 4     FL963UT  PC/postes de travail
#
#                                          Description Marque
# 0  HP BAC SLM for Business Process Monitor 200+ T...     HP
# 1                              HP Mini 110-1101TU PC     HP
# 2  HP VT491AA. Facteur de forme du clavier: Taill...     HP
# 3          HP Compaq Presario CQ61-318TX Notebook PC     HP
# 4                              HP xw4600 Workstation     HP

# %%
dfcat2_selected = dfcat2_selected.drop_duplicates(subset=['Ref_produit'])

# %%
dfcat2_selected= dfcat2_selected.dropna()
dfcat2_selected.describe()
# Out:
#        Ref_produit Categorie                              Description  Marque
# count       218761    218761                                   218761  218761
# unique      218761      1140                                   190137     209
# top       T6208AAE   Laptops  HP 1y 24x7 ProCurve Wireless SW Support      HP
# freq             1     31002                                      349   27504

# %%
dfcat2_selected['Description'][3600]
# Out:
# 'MSI Megabook CX500-601NE. Famille de processeur: Intel® Pentium® double cœur, Modèle de processeur: T4500, Fréquence du processeur: 2,3 GHz. Taille de l\'écran: 39,6 cm (15.6"), Résolution de l\'écran: 1366 x 768 pixels. Mémoire interne: 4 Go, Type de mémoire interne: DDR2-SDRAM. Capacité totale de stockage: 320 Go. Modèle d\'adaptateur graphique distinct: AMD Mobilty Radeon HD 4330. Système d\'exploitation installé: Windows 7 Home Premium. Couleur du produit: Noir. Poids: 2,48 kg'

# %%
dfcat2['ShortSummaryDescription'][3600]
# Out:
# 'MSI Megabook CX500-601NE, Intel® Pentium® double cœur, 2,3 GHz, 39,6 cm (15.6"), 1366 x 768 pixels, 4 Go, 320 Go'

# %%
dfcat2_selected.to_csv('dfcat2_clean.csv', index=False)

# %%
dfcat2_selected.to_csv('dfcat2_clean2.xlsx', index=False)

# %%
from IPython.display import display, HTML

# Créer un lien HTML pour le téléchargement
download_link = f'<a href="/kaggle/working/dfcat2_clean2.csv" download>Cliquer ici pour télécharger le fichier CSV</a>'
display(HTML(download_link))
# Out:
# <a href="/kaggle/working/dfcat2_clean2.csv" download>Cliquer ici pour télécharger le fichier CSV</a>
